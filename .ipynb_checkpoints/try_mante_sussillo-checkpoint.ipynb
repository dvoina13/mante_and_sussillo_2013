# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.linear_model import Ridge, LinearRegression

from numpy.linalg import qr

# %%
def define_data_set_old(num_tasks, T):

    x_dataset = torch.zeros([num_tasks, 4, T]); y_dataset = []; 
    
    #coin flips for ground truth
    context_ = 2*np.random.rand(num_tasks) - 1           #-1 = motion context; +1 = color context
    context = 2*((context_<0.0).astype(int))-1      #-1 = motion context; +1 = color context
    
    color_ = 2*np.random.rand(num_tasks) - 1             #-1 = blue; +1 = red
    color = 2*((color_<0.0).astype(int)) - 1               #-1 = blue; +1 = red
    
    motion_ = 2*np.random.rand(num_tasks) - 1 #0 = left; 1 = right
    motion = 2*((motion_<0.0).astype(int)) - 1 #0 = left; 1 = right

    y_dataset_full = torch.cat((torch.tensor(motion).unsqueeze(1), torch.tensor(color).unsqueeze(1), torch.tensor(context).unsqueeze(1)), dim=1)
    
    for n in range(num_tasks):

        if context[n] == -1:
            y_dataset.append(motion[n])        
        else:
            y_dataset.append(color[n])

        motion_signal = motion_[n] + motion_[n]/10*np.random.randn(T)        
        color_signal = color_[n] + color_[n]/10*np.random.randn(T)        

        motion_signal = 0.2*motion_signal; color_signal = 0.2*color_signal;
        
        x_dataset[n,0,:] = torch.tensor(motion_signal)
        x_dataset[n,1,:] = torch.tensor(color_signal)
        
        if context[n] == -1:
            x_dataset[n,2,:] = torch.tensor([1]*T)
            x_dataset[n,3,:] = torch.tensor([0]*T)
        else:
            x_dataset[n,2,:] = torch.tensor([0]*T)
            x_dataset[n,3,:] = torch.tensor([1]*T)

    y_dataset = torch.tensor(y_dataset)

    return x_dataset, y_dataset, y_dataset_full

# %%
def define_data_set(num_tasks, T):
    x_dataset = torch.zeros([num_tasks, 4, T])
    y_dataset = torch.zeros([num_tasks, T])
    
    # ground truth
    context_ = 2*np.random.rand(num_tasks) - 1
    context = 2*((context_<0.0).astype(int)) - 1

    color_ = 2*np.random.rand(num_tasks) - 1
    color = 2*((color_<0.0).astype(int)) - 1

    motion_ = 2*np.random.rand(num_tasks) - 1
    motion = 2*((motion_<0.0).astype(int)) - 1

    y_dataset_full = torch.cat((torch.tensor(motion).unsqueeze(1), torch.tensor(color).unsqueeze(1), torch.tensor(context).unsqueeze(1)), dim=1)

    fix_end = int(0.2 * T)
    stim_end = int(0.8 * T)

    for n in range(num_tasks):
        # target per timestep
        if context[n] == -1:
            y_dataset[n, fix_end:stim_end] = motion[n]
            #y_dataset[n] = motion[n]
        else:
            y_dataset[n, fix_end:stim_end] = color[n]
            #y_dataset[n] = color[n]

        # coherence
        coh = np.random.choice([0.05, 0.1, 0.2])  # slightly stronger
        # baseline noise
        motion_signal = 0.01*np.random.randn(T)
        color_signal  = 0.01*np.random.randn(T)
        # add stimulus
        motion_signal[fix_end:stim_end] += motion_[n] * coh
        color_signal[fix_end:stim_end]  += color_[n]  * coh

        x_dataset[n,0,:] = torch.tensor(motion_signal)
        x_dataset[n,1,:] = torch.tensor(color_signal)

        # context input
        if context[n] == -1:
            x_dataset[n,2,:] = 1.0
            x_dataset[n,3,:] = 0.0
        else:
            x_dataset[n,2,:] = 0.0
            x_dataset[n,3,:] = 1.0

    return x_dataset, y_dataset, y_dataset_full

# %%
x_dataset, y_dataset, y_dataset_full = define_data_set(10000, 750)
print("training data shapes", x_dataset.shape, y_dataset.shape)
training_dataset = TensorDataset(x_dataset, y_dataset)
training_data = DataLoader(training_dataset, batch_size=50, shuffle=True)

x_dataset2, y_dataset2, y_dataset_full2 = define_data_set(1000, 750)
print("training data shapes", x_dataset.shape, y_dataset.shape)
testing_dataset = TensorDataset(x_dataset2, y_dataset2)
testing_data = DataLoader(testing_dataset, batch_size=len(x_dataset2), shuffle=False)
# Out:
# training data shapes torch.Size([10000, 4, 750]) torch.Size([10000, 750])
# training data shapes torch.Size([10000, 4, 750]) torch.Size([10000, 750])

# %%
plt.figure()
plt.plot(x_dataset[1,0,:])
plt.xlabel("time")
plt.ylabel("x input (motion)")

plt.figure()
plt.plot(y_dataset[0,:])
plt.xlabel("time")
plt.ylabel("y output (ground truth)")
# Out:
# Text(0, 0.5, 'y output (ground truth)')

# %%
class RNN_neuro(nn.Module):
    
     def __init__(self, input_size=4, hidden_size=100, output_size = 1, batchsize = 50, dt=1, **kwargs):
        super().__init__()
         
        self.J_weights = nn.Parameter(1.5*torch.randn(hidden_size, hidden_size)/np.sqrt(hidden_size), requires_grad=True)
        self.nonlinear_fn = nn.Tanh()
    
        self.fc_in = nn.Linear(input_size, hidden_size)
        self.fc_out = nn.Linear(hidden_size, output_size)
        self.bias = nn.Parameter(torch.randn(hidden_size), requires_grad = True)

        self.std = 0.1
         
        self.tau = 10;
        self.dt = 1
        self.T = 750

        self.hidden_size = hidden_size
         
     def forward(self, input_):

        input_ = input_.float()
        batchsize = len(input_)
         
        h = torch.zeros(batchsize, self.hidden_size, device=input_.device)
        r = self.nonlinear_fn(h)

        all_h = []; all_r = []; 
        all_z = [];

        for t in range(self.T):
            temp = self.fc_in(input_[:,:,t]) + self.bias
            noise = self.std*torch.randn(batchsize, self.hidden_size) 

            h = h + self.dt/self.tau * (-h + r @ self.J_weights.T + temp + noise)
            r = self.nonlinear_fn(h)
            out = self.fc_out(r)

            all_h.append(h); all_r.append(r); 
            all_z.append(out)

        all_h = torch.stack(all_h, dim=2)
        all_r = torch.stack(all_r, dim=2)
        all_z = torch.stack(all_z, dim=2)
         
        return all_z, all_h, all_r

# %%
model = RNN_neuro()
model.float()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()   # Mante uses MSE on final output

# %%
def train_model(model, training_data, num_epochs=5, batchsize=50, lr=1e-3):

    epoch_loss_arr = []
    epoch_acc_arr = []
    y_arr = []; X_arr = [];
    z_final_arr = []; r_final_arr = []; h_final_arr = [];
    for epoch in range(num_epochs):

        epoch_loss = 0
        epoch_acc = 0
        epoch_total = 0
        for bid, batch in enumerate(training_data):

            X, y = batch
            batchsize, n_features, T = X.shape
            labels = y[:,int(T*0.5)]
            
            # forward pass
            all_z, all_h, all_r = model(X)
            
            # final output at last time step, shape (batch, 1)
            z_final = all_z[:, 0, int(T*0.8) - 1]

            optimizer.zero_grad()
            # MSE loss target needs shape (batch,)
            #loss = loss_fn(all_z[:,0,:750], y.float())
            loss = loss_fn(all_z[:,0,int(T*0.2):int(T*0.8)], y[:,int(T*0.2):int(T*0.8)].float())
            
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item()
            
            preds = (z_final > 0).long()*2 - 1
            correct = (preds == labels).sum().item()
            #correct = (preds == y).sum().item()
            epoch_acc += correct
            epoch_total += batchsize

            epoch_loss_arr.append(loss)
            epoch_acc_arr.append(float(correct)/batchsize)
            X_arr.append(X); y_arr.append(labels);

            z_final_arr.append(all_z); h_final_arr.append(all_h); r_final_arr.append(all_r);
            
            print(bid, correct/batchsize)
            
        epoch_acc = epoch_acc / epoch_total
        print(f"Epoch {epoch+1:3d}/{num_epochs} | Loss: {epoch_loss:.4f} | Acc: {epoch_acc*100:.2f}%")
        
    z_final_arr = torch.stack(z_final_arr).view(-1, model.T); 
    h_final_arr = torch.stack(h_final_arr).view(-1, model.hidden_size, model.T); 
    r_final_arr = torch.stack(r_final_arr).view(-1, model.hidden_size, model.T); 
    X_arr = torch.stack(X_arr); y_arr = torch.stack(y_arr).flatten()

    print("r_final_arr shapes etc", r_final_arr.shape, h_final_arr.shape, z_final_arr.shape)

    return epoch_loss_arr, epoch_acc_arr, X_arr, y_arr, h_final_arr, r_final_arr, z_final_arr

# %%
def test_model(model, testing_data):

    for bid, batch in enumerate(testing_data):

        X, y = batch
        batchsize, n_features, T = X.shape
        labels = y[:,int(T*0.5)]
        print("batchsize", batchsize)

        # forward pass
        all_z, all_h, all_r = model(X)
        
        # final output at last time step, shape (batch, 1)
        z_final = all_z[:, 0, int(T*0.8) - 1]

        #compute testing loss
        loss = loss_fn(all_z[:,0,int(T*0.2):int(T*0.8)], y[:,int(T*0.2):int(T*0.8)].float())


        preds = torch.sign(z_final)
        correct = (preds == y[:,int(T*0.5)]).sum().item()
        accuracy = correct/batchsize

    print(f"Testing loss is {loss.item()} and accuracy {accuracy*100}")
    return X, labels, all_r, all_h

# %%
epoch_loss, epoch_acc, X_arr, y_arr, h_final_arr, r_final_arr, z_final_arr = train_model(model, training_data)
# Out:
# 0 0.48
# 1 0.56
# 2 0.5
# 3 0.46
# 4 0.7
# 5 0.52
# 6 0.7
# 7 0.56
# 8 0.66
# 9 0.68
# 10 0.46
# 11 0.7
# 12 0.42
# 13 0.68
# 14 0.54
# 15 0.64
# 16 0.46
# 17 0.5
# 18 0.6
# 19 0.6
# 20 0.7
# 21 0.44
# 22 0.6
# 23 0.48
# 24 0.5
# 25 0.56
# 26 0.7
# 27 0.86
# 28 0.6
# 29 0.66
# 30 0.58
# 31 0.54
# 32 0.54
# 33 0.58
# 34 0.48
# 35 0.74
# 36 0.6
# 37 0.76
# 38 0.52
# 39 0.8
# 40 0.66
# 41 0.94
# 42 0.88
# 43 0.74
# 44 0.62
# 45 0.7
# 46 0.8
# 47 0.8
# 48 0.8
# 49 0.9
# 50 0.86
# 51 0.74
# 52 0.78
# 53 0.74
# 54 0.74
# 55 0.78
# 56 0.62
# 57 0.64
# 58 0.52
# 59 0.56
# 60 0.76
# 61 0.56
# 62 0.68
# 63 0.7
# 64 0.62
# 65 0.62
# 66 0.64
# 67 0.56
# 68 0.64
# 69 0.62
# 70 0.76
# 71 0.7
# 72 0.68
# 73 0.46
# 74 0.68
# 75 0.6
# 76 0.64
# 77 0.66
# 78 0.62
# 79 0.58
# 80 0.74
# 81 0.74
# 82 0.86
# 83 0.92
# 84 0.8
# 85 0.74
# 86 0.8
# 87 0.8
# 88 0.74
# 89 0.62
# 90 0.62
# 91 0.82
# 92 0.76
# 93 0.78
# 94 0.68
# 95 0.66
# 96 0.82
# 97 0.74
# 98 0.74
# 99 0.74
# 100 0.76
# 101 0.74
# 102 0.86
# 103 0.82
# 104 0.9
# 105 0.76
# 106 0.74
# 107 0.88
# 108 0.58
# 109 0.72
# 110 0.82
# 111 0.64
# 112 0.5
# 113 0.6
# 114 0.66
# 115 0.56
# 116 0.68
# 117 0.74
# 118 0.78
# 119 0.66
# 120 0.74
# 121 0.7
# 122 0.68
# 123 0.68
# 124 0.6
# 125 0.82
# 126 0.66
# 127 0.76
# 128 0.64
# 129 0.7
# 130 0.64
# 131 0.78
# 132 0.82
# 133 0.76
# 134 0.64
# 135 0.76
# 136 0.78
# 137 0.78
# 138 0.72
# 139 0.76
# 140 0.88
# 141 0.74
# 142 0.76
# 143 0.74
# 144 0.86
# 145 0.82
# 146 0.68
# 147 0.72
# 148 0.8
# 149 0.72
# 150 0.58
# 151 0.64
# 152 0.86
# 153 0.76
# 154 0.8
# 155 0.66
# 156 0.74
# 157 0.88
# 158 0.82
# 159 0.72
# 160 0.82
# 161 0.68
# 162 0.78
# 163 0.78
# 164 0.68
# 165 0.78
# 166 0.62
# 167 0.76
# 168 0.82
# 169 0.9
# 170 0.74
# 171 0.82
# 172 0.74
# 173 0.86
# 174 0.9
# 175 0.62
# 176 0.84
# 177 0.8
# 178 0.88
# 179 0.82
# 180 0.72
# 181 0.88
# 182 0.82
# 183 0.82
# 184 0.7
# 185 0.78
# 186 0.86
# 187 0.68
# 188 0.82
# 189 0.78
# 190 0.84
# 191 0.86
# 192 0.88
# 193 0.6
# 194 0.72
# 195 0.74
# 196 0.64
# 197 0.84
# 198 0.72
# 199 0.76
# Epoch   1/5 | Loss: 161.8665 | Acc: 70.74%
# 0 0.82
# 1 0.86
# 2 0.9
# 3 0.88
# 4 0.8
# 5 0.9
# 6 0.88
# 7 0.84
# 8 0.8
# 9 0.88
# 10 0.88
# 11 0.88
# 12 0.76
# 13 0.76
# 14 0.98
# 15 0.66
# 16 0.82
# 17 0.86
# 18 0.86
# 19 0.88
# 20 0.92
# 21 0.78
# 22 0.76
# 23 0.7
# 24 0.98
# 25 0.82
# 26 0.68
# 27 0.84
# 28 0.86
# 29 0.82
# 30 0.8
# 31 0.94
# 32 0.86
# 33 0.86
# 34 0.8
# 35 0.86
# 36 0.96
# 37 0.82
# 38 0.92
# 39 0.88
# 40 0.92
# 41 0.92
# 42 0.76
# 43 0.74
# 44 0.76
# 45 0.9
# 46 0.88
# 47 0.78
# 48 0.8
# 49 0.74
# 50 0.86
# 51 0.88
# 52 0.84
# 53 0.82
# 54 0.88
# 55 0.8
# 56 0.84
# 57 0.9
# 58 0.9
# 59 0.9
# 60 0.92
# 61 0.86
# 62 0.92
# 63 0.84
# 64 0.8
# 65 0.94
# 66 0.9
# 67 0.94
# 68 0.86
# 69 0.88
# 70 0.9
# 71 0.96
# 72 0.88
# 73 0.88
# 74 0.98
# 75 0.94
# 76 1.0
# 77 0.94
# 78 0.98
# 79 0.98
# 80 0.98
# 81 0.9
# 82 0.98
# 83 0.94
# 84 0.94
# 85 1.0
# 86 0.98
# 87 0.92
# 88 0.96
# 89 0.94
# 90 0.88
# 91 0.9
# 92 0.94
# 93 0.9
# 94 0.98
# 95 0.88
# 96 0.86
# 97 0.84
# 98 0.9
# 99 0.88
# 100 0.86
# 101 0.84
# 102 0.84
# 103 0.92
# 104 0.96
# 105 0.92
# 106 0.86
# 107 0.92
# 108 0.96
# 109 0.9
# 110 0.92
# 111 0.9
# 112 0.94
# 113 0.9
# 114 0.94
# 115 0.92
# 116 0.9
# 117 0.94
# 118 0.98
# 119 1.0
# 120 0.92
# 121 0.94
# 122 0.9
# 123 0.88
# 124 0.82
# 125 0.88
# 126 0.78
# 127 0.88
# 128 0.74
# 129 0.8
# 130 0.9
# 131 0.82
# 132 0.84
# 133 0.8
# 134 0.68
# 135 0.76
# 136 0.86
# 137 0.9
# 138 0.96
# 139 0.84
# 140 0.9
# 141 0.88
# 142 0.82
# 143 0.86
# 144 0.86
# 145 0.82
# 146 0.92
# 147 0.98
# 148 0.92
# 149 0.92
# 150 0.96
# 151 0.9
# 152 0.92
# 153 0.72
# 154 0.7
# 155 0.82
# 156 0.78
# 157 0.72
# 158 0.82
# 159 0.88
# 160 0.82
# 161 0.74
# 162 0.84
# 163 0.88
# 164 0.9
# 165 0.94
# 166 0.96
# 167 0.94
# 168 0.8
# 169 0.82
# 170 0.94
# 171 0.8
# 172 0.84
# 173 0.88
# 174 0.94
# 175 0.94
# 176 0.76
# 177 0.88
# 178 0.92
# 179 0.96
# 180 0.94
# 181 0.96
# 182 0.94
# 183 0.96
# 184 0.98
# 185 0.96
# 186 0.94
# 187 0.98
# 188 0.94
# 189 0.88
# 190 0.98
# 191 0.86
# 192 0.96
# 193 1.0
# 194 0.96
# 195 0.9
# 196 0.84
# 197 0.98
# 198 1.0
# 199 0.82
# Epoch   2/5 | Loss: 91.9113 | Acc: 87.99%
# 0 0.9
# 1 0.92
# 2 0.92
# 3 0.94
# 4 0.9
# 5 0.94
# 6 0.96
# 7 1.0
# 8 0.9
# 9 0.94
# 10 0.9
# 11 0.94
# 12 0.98
# 13 0.98
# 14 0.96
# 15 0.98
# 16 0.94
# 17 0.98
# 18 0.94
# 19 1.0
# 20 0.96
# 21 1.0
# 22 0.9
# 23 0.98
# 24 0.94
# 25 0.94
# 26 0.92
# 27 0.82
# 28 0.74
# 29 0.9
# 30 0.76
# 31 0.86
# 32 0.88
# 33 0.94
# 34 0.98
# 35 0.92
# 36 0.96
# 37 0.92
# 38 0.94
# 39 0.92
# 40 0.98
# 41 0.94
# 42 0.88
# 43 0.9
# 44 0.96
# 45 0.98
# 46 0.96
# 47 0.98
# 48 0.84
# 49 0.94
# 50 0.68
# 51 0.86
# 52 0.82
# 53 0.94
# 54 0.96
# 55 0.94
# 56 0.84
# 57 0.84
# 58 0.76
# 59 0.94
# 60 0.9
# 61 0.74
# 62 0.86
# 63 0.84
# 64 0.86
# 65 0.94
# 66 0.9
# 67 0.92
# 68 0.98
# 69 0.9
# 70 0.96
# 71 0.94
# 72 1.0
# 73 0.98
# 74 0.96
# 75 0.94
# 76 0.96
# 77 0.96
# 78 0.92
# 79 0.92
# 80 0.96
# 81 0.98
# 82 0.92
# 83 0.96
# 84 0.94
# 85 0.86
# 86 0.88
# 87 0.78
# 88 0.92
# 89 0.8
# 90 0.98
# 91 0.92
# 92 0.88
# 93 0.8
# 94 0.82
# 95 0.94
# 96 0.86
# 97 0.84
# 98 0.88
# 99 0.78
# 100 0.84
# 101 0.78
# 102 0.94
# 103 0.82
# 104 0.92
# 105 0.92
# 106 0.9
# 107 0.82
# 108 0.8
# 109 0.92
# 110 0.96
# 111 0.86
# 112 0.88
# 113 0.92
# 114 0.84
# 115 0.88
# 116 0.9
# 117 0.88
# 118 0.82
# 119 0.9
# 120 0.96
# 121 0.82
# 122 0.88
# 123 0.88
# 124 0.86
# 125 0.9
# 126 0.94
# 127 0.92
# 128 0.86
# 129 0.86
# 130 0.82
# 131 0.82
# 132 0.9
# 133 0.92
# 134 0.9
# 135 0.98
# 136 0.92
# 137 0.84
# 138 0.88
# 139 0.98
# 140 0.98
# 141 0.88
# 142 0.9
# 143 0.86
# 144 0.96
# 145 0.96
# 146 0.96
# 147 0.92
# 148 0.92
# 149 1.0
# 150 0.96
# 151 0.88
# 152 0.96
# 153 1.0
# 154 1.0
# 155 0.92
# 156 1.0
# 157 0.98
# 158 0.96
# 159 0.96
# 160 0.94
# 161 0.98
# 162 0.96
# 163 0.98
# 164 0.96
# 165 0.92
# 166 0.96
# 167 0.96
# 168 0.98
# 169 0.98
# 170 0.96
# 171 0.98
# 172 0.9
# 173 0.92
# 174 0.9
# 175 0.96
# 176 0.98
# 177 0.92
# 178 0.92
# 179 0.98
# 180 0.94
# 181 0.94
# 182 0.98
# 183 0.94
# 184 1.0
# 185 0.98
# 186 1.0
# 187 0.92
# 188 0.98
# 189 0.98
# 190 1.0
# 191 0.98
# 192 0.98
# 193 0.96
# 194 1.0
# 195 0.92
# 196 0.98
# 197 0.96
# 198 0.88
# 199 0.94
# Epoch   3/5 | Loss: 66.8441 | Acc: 91.86%
# 0 0.98
# 1 0.84
# 2 0.88
# 3 0.9
# 4 0.96
# 5 0.9
# 6 0.84
# 7 0.9
# 8 0.94
# 9 0.9
# 10 0.94
# 11 0.86
# 12 0.92
# 13 0.88
# 14 0.86
# 15 0.92
# 16 0.94
# 17 0.9
# 18 0.94
# 19 0.96
# 20 0.9
# 21 0.98
# 22 0.94
# 23 0.98
# 24 0.96
# 25 0.98
# 26 1.0
# 27 1.0
# 28 0.98
# 29 0.96
# 30 0.96
# 31 0.98
# 32 0.98
# 33 0.98
# 34 0.98
# 35 0.98
# 36 0.98
# 37 0.98
# 38 0.94
# 39 0.96
# 40 0.94
# 41 1.0
# 42 0.86
# 43 0.96
# 44 0.92
# 45 0.86
# 46 0.9
# 47 1.0
# 48 0.92
# 49 0.86
# 50 0.98
# 51 0.96
# 52 0.86
# 53 0.92
# 54 0.96
# 55 0.94
# 56 0.96
# 57 0.96
# 58 0.92
# 59 0.92
# 60 0.94
# 61 0.78
# 62 0.94
# 63 0.9
# 64 0.94
# 65 0.92
# 66 0.94
# 67 0.9
# 68 0.88
# 69 0.82
# 70 0.96
# 71 0.96
# 72 0.92
# 73 0.86
# 74 0.88
# 75 0.98
# 76 0.98
# 77 0.92
# 78 0.94
# 79 0.9
# 80 0.92
# 81 0.96
# 82 0.92
# 83 0.98
# 84 0.9
# 85 0.96
# 86 0.98
# 87 0.98
# 88 0.92
# 89 0.96
# 90 1.0
# 91 0.9
# 92 0.94
# 93 0.96
# 94 0.94
# 95 1.0
# 96 0.94
# 97 0.88
# 98 0.98
# 99 1.0
# 100 0.98
# 101 0.92
# 102 0.84
# 103 0.98
# 104 0.96
# 105 0.96
# 106 0.82
# 107 0.94
# 108 0.94
# 109 0.98
# 110 0.86
# 111 1.0
# 112 0.94
# 113 0.96
# 114 0.96
# 115 0.92
# 116 0.94
# 117 0.94
# 118 0.96
# 119 0.94
# 120 0.94
# 121 0.94
# 122 0.98
# 123 0.88
# 124 0.82
# 125 0.94
# 126 1.0
# 127 0.9
# 128 0.88
# 129 0.94
# 130 0.92
# 131 0.98
# 132 0.92
# 133 0.96
# 134 0.88
# 135 1.0
# 136 0.92
# 137 0.9
# 138 1.0
# 139 0.96
# 140 1.0
# 141 0.96
# 142 0.96
# 143 1.0
# 144 0.98
# 145 0.98
# 146 0.98
# 147 0.98
# 148 0.98
# 149 0.92
# 150 0.92
# 151 1.0
# 152 0.98
# 153 1.0
# 154 0.96
# 155 1.0
# 156 1.0
# 157 0.96
# 158 1.0
# 159 0.86
# 160 0.94
# 161 0.94
# 162 0.96
# 163 0.98
# 164 0.94
# 165 0.98
# 166 0.9
# 167 1.0
# 168 0.92
# 169 0.9
# 170 0.94
# 171 0.9
# 172 0.96
# 173 0.94
# 174 0.82
# 175 0.96
# 176 0.9
# 177 0.94
# 178 0.98
# 179 0.98
# 180 0.9
# 181 0.88
# 182 0.9
# 183 0.88
# 184 0.92
# 185 0.92
# 186 0.76
# 187 0.9
# 188 0.96
# 189 0.92
# 190 0.98
# 191 0.88
# 192 0.88
# 193 0.9
# 194 0.96
# 195 0.9
# 196 1.0
# 197 0.9
# 198 0.86
# 199 0.96
# Epoch   4/5 | Loss: 57.2468 | Acc: 93.60%
# 0 0.94
# 1 0.86
# 2 1.0
# 3 0.96
# 4 0.98
# 5 0.98
# 6 0.98
# 7 0.98
# 8 0.96
# 9 0.96
# 10 0.96
# 11 0.9
# 12 0.94
# 13 1.0
# 14 0.94
# 15 0.86
# 16 0.96
# 17 0.9
# 18 0.94
# 19 0.92
# 20 0.94
# 21 0.82
# 22 0.9
# 23 0.9
# 24 0.94
# 25 0.94
# 26 0.92
# 27 0.96
# 28 0.94
# 29 0.96
# 30 0.98
# 31 0.92
# 32 0.98
# 33 0.94
# 34 1.0
# 35 1.0
# 36 0.98
# 37 0.98
# 38 0.96
# 39 1.0
# 40 1.0
# 41 0.98
# 42 0.94
# 43 0.98
# 44 0.96
# 45 0.96
# 46 0.96
# 47 0.92
# 48 1.0
# 49 0.94
# 50 0.94
# 51 0.92
# 52 0.96
# 53 0.94
# 54 0.9
# 55 0.96
# 56 0.96
# 57 0.98
# 58 0.92
# 59 0.9
# 60 1.0
# 61 0.96
# 62 0.9
# 63 0.92
# 64 0.94
# 65 0.94
# 66 0.98
# 67 0.92
# 68 0.94
# 69 0.94
# 70 0.94
# 71 0.94
# 72 0.92
# 73 1.0
# 74 0.96
# 75 1.0
# 76 0.96
# 77 0.9
# 78 0.86
# 79 0.98
# 80 0.86
# 81 0.92
# 82 0.96
# 83 0.82
# 84 0.88
# 85 0.96
# 86 0.96
# 87 0.86
# 88 0.88
# 89 0.82
# 90 0.92
# 91 0.98
# 92 0.92
# 93 0.84
# 94 0.8
# 95 0.84
# 96 0.94
# 97 0.98
# 98 0.98
# 99 0.94
# 100 0.88
# 101 0.98
# 102 0.9
# 103 0.9
# 104 0.98
# 105 1.0
# 106 0.9
# 107 0.92
# 108 0.96
# 109 0.94
# 110 0.88
# 111 0.96
# 112 0.92
# 113 0.96
# 114 0.9
# 115 0.9
# 116 0.94
# 117 0.88
# 118 0.96
# 119 0.94
# 120 0.78
# 121 0.92
# 122 0.98
# 123 0.96
# 124 0.92
# 125 0.92
# 126 0.94
# 127 1.0
# 128 0.94
# 129 0.94
# 130 0.98
# 131 0.94
# 132 1.0
# 133 0.82
# 134 0.98
# 135 0.92
# 136 0.96
# 137 0.92
# 138 0.94
# 139 0.9
# 140 0.96
# 141 0.96
# 142 0.94
# 143 0.88
# 144 0.88
# 145 0.9
# 146 0.92
# 147 0.94
# 148 0.94
# 149 0.94
# 150 0.82
# 151 0.78
# 152 0.98
# 153 0.96
# 154 0.98
# 155 0.88
# 156 0.94
# 157 0.88
# 158 0.96
# 159 0.96
# 160 0.98
# 161 1.0
# 162 1.0
# 163 1.0
# 164 0.98
# 165 0.98
# 166 0.92
# 167 0.98
# 168 1.0
# 169 0.92
# 170 0.88
# 171 0.96
# 172 0.94
# 173 0.96
# 174 0.98
# 175 0.96
# 176 0.96
# 177 0.94
# 178 0.94
# 179 0.96
# 180 0.88
# 181 0.94
# 182 0.84
# 183 0.88
# 184 0.92
# 185 0.96
# 186 0.98
# 187 0.88
# 188 0.92
# 189 0.92
# 190 0.96
# 191 0.96
# 192 0.98
# 193 1.0
# 194 0.94
# 195 0.98
# 196 0.94
# 197 0.94
# 198 0.96
# 199 0.96
# Epoch   5/5 | Loss: 53.0492 | Acc: 93.75%
# r_final_arr shapes etc torch.Size([50000, 100, 750]) torch.Size([50000, 100, 750]) torch.Size([50000, 750])

# %%
X, y, all_r, all_h = test_model(model, testing_data)
X.shape, y.shape, all_r.shape, all_h.shape
# Out:
# batchsize 1000
# Testing loss is 0.24850641191005707 and accuracy 92.5
# (torch.Size([1000, 4, 750]),
#  torch.Size([1000]),
#  torch.Size([1000, 100, 750]),
#  torch.Size([1000, 100, 750]))

# %%
plt.figure()
plt.plot(epoch_acc, "-*")
plt.xlabel("trial")
plt.ylabel("accuracy")

epoch_loss = [epoch_loss[i].item() for i in range(len(epoch_loss))]
plt.figure()
plt.plot(epoch_loss, "--*")
plt.xlabel("trial")
plt.ylabel("loss")
# Out:
# Text(0, 0.5, 'loss')

# %%
def plot_neural_trajectories(all_r, neuron_ids=[0,1,2], trial_id=0):
    r = all_r[trial_id,:,:].detach().cpu().numpy()  # shape (hidden, T)
    T = r.shape[1]

    plt.figure(figsize=(8,4))
    for nid in neuron_ids:
        plt.plot(range(T), r[nid,:], label=f"Neuron {nid}")
    
    plt.xlabel("Time")
    plt.ylabel("Activity (r)")
    plt.title(f"Neural Trajectories (Trial {trial_id})")
    plt.legend()
    plt.tight_layout()
    plt.show()

print("r_final_arr.shape", r_final_arr.shape)
plot_neural_trajectories(r_final_arr)
# Out:
# r_final_arr.shape torch.Size([50000, 100, 750])

# %%
y_ind0 = np.where(y == -1)[0]
y_ind1 = np.where(y == 1)[0]

context_ = y_dataset_full2[:,2]
context_ind0 = np.where(context_==-1)[0]
context_ind1 = np.where(context_==1)[0]

motion_ = y_dataset_full2[:,0]
motion_ind0 = np.where(motion_==-1)[0]
motion_ind1 = np.where(motion_==1)[0]

color_ = y_dataset_full2[:,1]
color_ind0 = np.where(color_==-1)[0]
color_ind1 = np.where(color_==1)[0]

# %%
def plot_pca_trajectories(all_r, trial_ids=[0,1], labels=None):
    # all_r: (batch, hidden, T)
    all_r = all_r.detach().cpu().numpy()

    plt.figure(figsize=(8,6))

    for idx, trial in enumerate(trial_ids):
        r = all_r[trial,:,:]  # (hidden, T)
        pca = PCA(n_components=3)
        traj = pca.fit_transform(r.T)  # (T, 3)

        ax = plt.subplot(111, projection='3d')
        ax.plot(traj[:,0], traj[:,1], traj[:,2], label=f"Trial {trial}")

        if labels is not None:
            ax.set_title(labels[trial])

    ax.set_xlabel("PC1")
    ax.set_ylabel("PC2")
    ax.set_zlabel("PC3")
    #ax.legend()
    plt.tight_layout()
    plt.show()

def plot_pca_trajectories_2d(all_r, trial_ids=[0,1], labels=None):
    # all_r: (batch, hidden, T)
    all_r = all_r.detach().cpu().numpy()

    plt.figure(figsize=(8,6))
    traj_avg = np.zeros((all_r.shape[2],2))
    
    for idx, trial in enumerate(trial_ids):
        r = all_r[trial,:,:]  # (hidden, T)
        pca = PCA(n_components=2)
        traj = pca.fit_transform(r.T)  # (T, 3)

        ax = plt.subplot(111)
        ax.plot(traj[:,0], traj[:,1], label=f"Trial {trial}")

        traj_avg += traj;
        if labels is not None:
            ax.set_title(labels[trial])

    ax.set_xlabel("PC1")
    ax.set_ylabel("PC2")
    #ax.legend()
    plt.tight_layout()
    plt.show()

    return traj_avg/len(trial_ids)

# %%
#list_of_trials = list(context_ind0[:100]) + list(context_ind1[:100])
list_of_trials = list(y_ind0[:100]) + list(y_ind1[:100]) #some trials choosing +1, some trials choosing -1
plot_pca_trajectories(all_r, trial_ids=list_of_trials)

# %%
traj_avg1 = plot_pca_trajectories_2d(r_final_arr, trial_ids=y_ind0[:100])
traj_avg2 = plot_pca_trajectories_2d(r_final_arr, trial_ids=y_ind1[:100])

plt.plot(traj_avg1[:,0],traj_avg1[:,1]) 
plt.plot(traj_avg2[:,0],traj_avg2[:,1]) 
plt.xlabel("PC1")
plt.ylabel("PC2")
# Out:
# Text(0, 0.5, 'PC2')

# %%
def compute_context_axis(all_r, X_input):
    """
    all_r: (batch, hidden, T)
    y_full: (batch, 3) -> (motion, color, context)
    """
    context = 2*np.where(X_input[:,2:3,0]==1)[0] - 1  # -1 or +1
    r = all_r.mean(dim=2)  # average over time (batch, hidden)

    r_ctx1 = r[context == 1].mean(dim=0)
    r_ctxm1 = r[context == -1].mean(dim=0)

    context_axis = r_ctx1 - r_ctxm1  # vector in hidden space
    context_axis = context_axis / context_axis.norm()

    return context_axis

# %%
def compute_choice_axes(model, all_r, y):
    
    # model.fc_out.weight: (1, hidden)
    choice_axis_model = model.fc_out.weight.data.squeeze(0)          # torch (H,)
    choice_axis_model = choice_axis_model / choice_axis_model.norm()

    # regression-based choice axis (fit final choice using population at final time)
    with torch.no_grad():
        R_final = all_r[:, :, -1].detach().cpu().numpy()   # (B, H)
        y_np = y.reshape(-1, 1)              # (B,1)
    # ridge to get direction in H space: solve R_final @ w = y
    ridge = Ridge(alpha=1.0, fit_intercept=False)
    ridge.fit(R_final, y_np)
    w = ridge.coef_.reshape(-1)    # shape (H,)
    w = w / np.linalg.norm(w)
    choice_axis_ridge = torch.from_numpy(w).float()

    return choice_axis_model.detach(), choice_axis_ridge

# %%
def project_and_summary(all_r, axis, y=None):
    # axis: torch (H,) or numpy (H,)
    if isinstance(axis, np.ndarray):
        axis = torch.from_numpy(axis).float()
    axis = axis.to(all_r.device)
    
    # project on the axis; proj: (B, T)
    #“At each time step, how much does the neural population point in the direction of this axis?”
    #proj[b,t] = sum_{h=1}^{H} all_r[b,h,t]⋅axis[h], ie sum over units in hidden layer
    proj = torch.einsum('bht,h->bt', all_r, axis)
    
    proj_np = proj.detach().cpu().numpy()

    print("proj_np.shape", proj_np.shape)
    #separate projectiom across trials for choice +1/-1, and take mean/std of projections
    mean_plus = proj_np[(y==1).cpu().numpy(),:].mean(axis=0) if y is not None else None
    mean_minus= proj_np[(y==-1).cpu().numpy(),:].mean(axis=0) if y is not None else None
    sem_plus  = proj_np[(y==1).cpu().numpy(),:].std(axis=0, ddof=1) / np.sqrt((y==1).sum().item()) if y is not None else None
    sem_minus = proj_np[(y==-1).cpu().numpy(),:].std(axis=0, ddof=1) / np.sqrt((y==-1).sum().item()) if y is not None else None

    T = mean_plus.shape[0]
    t = np.arange(T)
    plt.figure(figsize=(7,4))
    
    ind0 = np.where((y==-1).cpu().numpy())[0]
    ind0 = ind0[np.random.choice(len(ind0),100)] #ind0[-100:]
    ind1 = np.where((y==1).cpu().numpy())[0]
    ind1 = ind1[np.random.choice(len(ind1),100)] #ind1[-100:]
    plt.plot(t, proj_np[ind0, :].T, color='blue', alpha=0.2)
    plt.plot(t, proj_np[ind1,:].T, color = 'orange', alpha=0.2)
    plt.xlabel("Time")
    plt.ylabel("Projection")
   
    plt.figure()
    plt.fill_between(t, mean_minus-sem_minus, mean_minus+sem_minus, alpha=0.5, color='C0')
    plt.plot(t, mean_minus, label='-1', color='C0')
    plt.fill_between(t, mean_plus-sem_plus, mean_plus+sem_plus, alpha=0.5, color='C1')
    plt.plot(t, mean_plus, label='+1', color='C1')
    plt.xlabel('Time')
    plt.ylabel('Projection')
    plt.title('Projection over time')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return proj_np

# %%
choice_axis_model, choice_axis_ridge = compute_choice_axes(model, all_r, y)
#context_axis = compute_context_axis(r_final_arr, X_arr)
proj_np = project_and_summary(all_r, choice_axis_model, y)
# Out:
# proj_np.shape (1000, 750)

# %%
def compute_dprime_over_time(proj, y):
    # proj: (B, T)
    mu_p = proj[y==1].mean(axis=0)
    mu_m = proj[y==-1].mean(axis=0)
    var_p = proj[y==1].var(axis=0, ddof=1)
    var_m = proj[y==-1].var(axis=0, ddof=1)
    # pooled sd
    sd_pooled = np.sqrt(0.5*(var_p + var_m))
    dprime = (mu_p - mu_m) / (sd_pooled + 1e-10)
    return dprime

# --- 5) PCA on trial-averaged conditions and plotting 3D ---------------------

def trial_average_by_condition(all_r, y_dataset_full):
    # y_full[:,0]=motion,[:,1]=color,[:,2]=context
    motion = y_full[:,0].cpu().numpy()
    color  = y_full[:,1].cpu().numpy()
    context = y_full[:,2].cpu().numpy()
    conds = {}
    for m in [-1,1]:
        for c in [-1,1]:
            for ctx in [-1,1]:
                mask = (motion==m) & (color==c) & (context==ctx)
                if mask.sum() == 0:
                    continue
                # average over trials for that condition
                avg = all_r[mask].mean(dim=0).cpu().numpy()   # (H, T)
                conds[(m,c,ctx)] = avg
    return conds

dprime = compute_dprime_over_time(proj_np, y.cpu())
plt.figure(); plt.plot(dprime); plt.xlabel('Time'); plt.ylabel("d'"); plt.title("d' over time"); plt.show()

# %%
def trial_average_by_condition(all_r, y_full):
    # y_full[:,0]=motion,[:,1]=color,[:,2]=context
    motion = y_full[:,0].cpu().numpy()
    color  = y_full[:,1].cpu().numpy()
    context = y_full[:,2].cpu().numpy()
    conds = {}
    for m in [-1,1]:
        for c in [-1,1]:
            for ctx in [-1,1]:
                mask = (motion==m) & (color==c) & (context==ctx)
                if mask.sum() == 0:
                    continue

                # average over trials for that condition
                avg = all_r[mask].mean(dim=0).cpu().detach().numpy()   # (H, T) #average trajectory over each condition
                conds[(m,c,ctx)] = avg
    return conds

def pca_plot_condition_trajectories(cond_trajs, n_components=3):
    # stack and fit PCA on concatenated time X conditions
    trajs = []
    keys = []
    for k,v in cond_trajs.items():
        # v: (H, T) -> transpose to (T, H)
        trajs.append(v.T)
        keys.append(k)

    big = np.concatenate(trajs, axis=0)   # (T*conds, H)
    print("trajs.shape", big.shape)

    pca = PCA(n_components=n_components)
    big_p = pca.fit_transform(big)        # (T*conds, n_components)
    print("big_p.shape", big_p.shape)
        
    # split back and plot
    idx = 0
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(7,6))
    ax = fig.add_subplot(111, projection='3d')
    for k,v in zip(keys, trajs):
        T = v.shape[0]
        seg = big_p[idx:idx+T]
        ctx = k[2]
        color = 'C0' if ctx==-1 else 'C1'
        ax.plot(seg[:,0], seg[:,1], seg[:,2], color=color, alpha=0.9)
        idx += T
    ax.set_xlabel('PC1'); ax.set_ylabel('PC2'); ax.set_zlabel('PC3')
    plt.title('Condition-averaged PCA trajectories')
    plt.show()

# %%
conds = trial_average_by_condition(all_r, y_dataset_full2)
pca_plot_condition_trajectories(conds)
# Out:
# trajs.shape (6000, 100)
# big_p.shape (6000, 3)

# %%
"""
# --- 6) endpoint scatter in 2D (PC1-PC2) -----------------------------------
def endpoint_scatter(R_pca, y_full):
    endpoints = R_pca[:, -1, :2]
    ctx = y_full[:,2].cpu().numpy()
    plt.figure(figsize=(6,5))
    plt.scatter(endpoints[ctx==-1,0], endpoints[ctx==-1,1], label='motion ctx', alpha=0.7)
    plt.scatter(endpoints[ctx== 1,0], endpoints[ctx== 1,1], label='color ctx', alpha=0.7)
    plt.legend()
    plt.xlabel('PC1'); plt.ylabel('PC2'); plt.title('Endpoints (PC1-PC2)')
    plt.show()


B,H,T = r_final_arr[-10000:,:,:].shape
R_flat = r_final_arr[-10000:,:,:].cpu().detach().numpy().transpose(0,2,1).reshape(-1, H)
pca = PCA(n_components=3)
R_pca_flat = pca.fit_transform(R_flat)
R_pca = R_pca_flat.reshape(B, T, 3)
endpoint_scatter(R_pca, y_dataset_full)
"""
# Out:
# "\n# --- 6) endpoint scatter in 2D (PC1-PC2) -----------------------------------\ndef endpoint_scatter(R_pca, y_full):\n    endpoints = R_pca[:, -1, :2]\n    ctx = y_full[:,2].cpu().numpy()\n    plt.figure(figsize=(6,5))\n    plt.scatter(endpoints[ctx==-1,0], endpoints[ctx==-1,1], label='motion ctx', alpha=0.7)\n    plt.scatter(endpoints[ctx== 1,0], endpoints[ctx== 1,1], label='color ctx', alpha=0.7)\n    plt.legend()\n    plt.xlabel('PC1'); plt.ylabel('PC2'); plt.title('Endpoints (PC1-PC2)')\n    plt.show()\n\n\nB,H,T = r_final_arr[-10000:,:,:].shape\nR_flat = r_final_arr[-10000:,:,:].cpu().detach().numpy().transpose(0,2,1).reshape(-1, H)\npca = PCA(n_components=3)\nR_pca_flat = pca.fit_transform(R_flat)\nR_pca = R_pca_flat.reshape(B, T, 3)\nendpoint_scatter(R_pca, y_dataset_full)\n"

# %%
#compute axes of motion, color, choice, and context like in the paper

# %%
def compute_betas(all_r, y_full):
    # all_r: (B, H, T)
    B, H, T = all_r.shape
    betas = np.zeros((T, H, 4))  # choice, motion, color, context

    choice  = y_full[:,0].cpu().numpy()
    motion  = y_full[:,1].cpu().numpy()
    color   = y_full[:,2].cpu().numpy()
    context = y_full[:,2].cpu().numpy()
    constant = torch.ones_like(y_full[:,0]).cpu().numpy()
    
    X = np.stack([choice, motion, color, context, constant], axis=1)

    for t in range(T):
        for h in range(H):
            y = all_r[:,h,t].cpu().detach().numpy()
            reg = LinearRegression().fit(X, y)
            betas[t,h,:] = reg.coef_[:4]

    return betas

def max_norm_axes(betas):
    # betas: (T, H, 4)
    axes = []
    for k in range(4):
        norms = np.linalg.norm(betas[:,:,k], axis=1)
        t_star = norms.argmax()
        axes.append(betas[t_star,:,k])
    return np.stack(axes)

betas = compute_betas(all_r, y_dataset_full2)
print("betas.shape", betas.shape)

beta_axes = max_norm_axes(betas)

Q, R = qr(beta_axes.T)
axes_orth = Q.T
# Out:
# betas.shape (750, 100, 4)

# %%
axes_orth.shape, all_r.shape
# Out:
# ((4, 100), torch.Size([1000, 100, 750]))

# %%
all_r.shape
# Out:
# torch.Size([1000, 100, 750])

# %%
def project_and_summary(all_r, axis, y=None, to_plot=[0,1], col=0, supress = False):
    # axis: torch (H,) or numpy (H,)
    if isinstance(axis, np.ndarray):
        axis = torch.from_numpy(axis).float()
    axis = axis.to(all_r.device)
    N, hidden_u, T = all_r.shape
    
    # project on the axis; proj: (B, T)
    #“At each time step, how much does the neural population point in the direction of this axis?”
    #proj[b,t] = sum_{h=1}^{H} all_r[b,h,t]⋅axis[h], ie sum over units in hidden layer

    print("all_r.shape", all_r.shape, axis.shape)
    print(np.transpose(axis, (1,0)).shape)

    #proj = torch.einsum('bht,h->bt', all_r, axis)
    r_btH = all_r.transpose(1, 2)   # [B, T, H]
    axis = axis.transpose(1,0)
    proj = torch.matmul(r_btH, axis)  # [B, T, 4]
    proj_np = proj.detach().cpu().numpy()

    #separate projectiom across trials for choice +1/-1, and take mean/std of projections
    mean_plus = proj_np[(y==1).cpu().numpy(),:,:].mean(axis=0) if y is not None else None
    mean_minus= proj_np[(y==-1).cpu().numpy(),:,:].mean(axis=0) if y is not None else None
    sem_plus  = proj_np[(y==1).cpu().numpy(),:,:].std(axis=0, ddof=1) / np.sqrt((y==1).sum().item()) if y is not None else None
    sem_minus = proj_np[(y==-1).cpu().numpy(),:,:].std(axis=0, ddof=1) / np.sqrt((y==-1).sum().item()) if y is not None else None

    T = mean_plus.shape[0]
    t = np.arange(T)
    plt.figure(figsize=(7,4))

    ind0 = np.where((y==-1).cpu().numpy())[0]
    ind1 = np.where((y==1).cpu().numpy())[0]

    axis_names = []
    if 0 in to_plot:
        axis_names.append("choice axis")
    if 1 in to_plot:
        axis_names.append("motion axis")
    if 2 in to_plot:
        axis_names.append("color axis")
    if 3 in to_plot:
        axis_names.append("context axis")

    plt.figure()
    if len(ind0) != 0:
        ind0 = ind0[np.random.choice(len(ind0),10)] #ind0[-100:]
        plt.plot(proj_np[ind0, int(0.2*T):int(0.8*T), to_plot[0]].T, proj_np[ind0, int(0.2*T):int(0.8*T), to_plot[1]].T, color = "C" + str(col))

    if len(ind1) != 0:
        ind1 = ind1[np.random.choice(len(ind1),10)] #ind1[-100:]
        plt.plot(proj_np[ind1, int(0.2*T):int(0.8*T), to_plot[0]].T, proj_np[ind1, int(0.2*T):int(0.8*T), to_plot[1]].T, color = "C" + str(col+1))
    plt.xlabel(axis_names[0])
    plt.ylabel(axis_names[1])

    if supress == False:
        plt.figure()
        print("mean_minus, sem_minus", mean_minus.shape, sem_minus.shape)
        plt.fill_between(t, mean_minus[:,0]-sem_minus[:,0], mean_minus[:,0]+sem_minus[:,0], alpha=0.5, color='C1')
        plt.plot(t, mean_minus[:,0], label='-1', color='C1')
        plt.fill_between(t, mean_plus[:,0]-sem_plus[:,0], mean_plus[:,0]+sem_plus[:,0], alpha=0.5, color='C0')
        plt.plot(t, mean_plus[:,0], label='+1', color='C0')
        plt.xlabel('Time')
        plt.ylabel('Projection')
        plt.title('Projection over time')
        plt.legend()
        plt.tight_layout()
        plt.show()

    return proj_np

# %%
proj = project_and_summary(all_r, axes_orth, y)
# Out:
# all_r.shape torch.Size([1000, 100, 750]) torch.Size([4, 100])
# torch.Size([100, 4])
# mean_minus, sem_minus (750, 4) (750, 4)

# %%
#look at dynamics, motion context
ind_to_plot0 = list(set(motion_ind0) & set(context_ind0))
ind_to_plot1 = list(set(motion_ind1) & set(context_ind0))

proj = project_and_summary(all_r[ind_to_plot0+ind_to_plot1, :, :], axes_orth, y[ind_to_plot0+ind_to_plot1], supress = True)
proj = project_and_summary(all_r[ind_to_plot0+ind_to_plot1, :, :], axes_orth, y[ind_to_plot0+ind_to_plot1], to_plot=[0,2], supress = True)
# Out:
# all_r.shape torch.Size([496, 100, 750]) torch.Size([4, 100])
# torch.Size([100, 4])
# all_r.shape torch.Size([496, 100, 750]) torch.Size([4, 100])
# torch.Size([100, 4])

# %%
#look at dynamics, color context
ind_to_plot0 = list(set(color_ind0) & set(context_ind1))
ind_to_plot1 = list(set(color_ind1) & set(context_ind1))
proj = project_and_summary(all_r[ind_to_plot0+ind_to_plot1, :, :], axes_orth, y[ind_to_plot0+ind_to_plot1], to_plot=[0,2], supress=True)
proj = project_and_summary(all_r[ind_to_plot0+ind_to_plot1, :, :], axes_orth, y[ind_to_plot0+ind_to_plot1], to_plot=[0,1], supress=True)
# Out:
# all_r.shape torch.Size([504, 100, 750]) torch.Size([4, 100])
# torch.Size([100, 4])
# all_r.shape torch.Size([504, 100, 750]) torch.Size([4, 100])
# torch.Size([100, 4])

# %%
def model_vector_field(h, x_const, model):
    """
    Computes F(h) = -h + J tanh(h) + Bx + b
    """

    r = model.nonlinear_fn(h)
    # J r  (shape: hidden_size)
    Jr = r @ model.J_weights.T

    # B x  (shape: hidden_size)
    Bx = model.fc_in(x_const)

    # F(h)
    F = -h + Jr + Bx + model.bias

    return F

# %%
def find_fixed_point(X, all_h, model, trial, time_idx, max_iter=1000, tol=1e-8):

    # initial guess from trajectory
    h = all_h[trial, :, time_idx].clone().detach().requires_grad_(True)

    # hold input fixed at this timestep
    x_const = X[trial, :, time_idx]

    optimizer = torch.optim.Adam([h], lr=1e-2)
    loss_arr = []; h_star_arr = []
    for i in range(max_iter):

        F = model_vector_field(h, x_const, model)
        loss = (F**2).sum()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if i % 100 == 0:
            print(f"Iter {i}, loss = {loss.item():.3e}")

        if loss.item() < tol:
            break

        loss_arr.append(loss.item()); h_star_arr.append(h.detach().cpu().clone().numpy())
    h_star = h.detach()
    r_star = model.nonlinear_fn(h_star)

    return h_star, r_star, loss.item(), loss_arr, h_star_arr
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 684

# %%
h_star, r_star, final_loss, loss_arr, h_star_arr = find_fixed_point(X=X, all_h=all_h, model=model, trial=0, time_idx=int(0.7 * 750))
print("final FP loss:", final_loss)
# Out:
# Iter 0, loss = 8.932e-02
# final FP loss: 1.0549299531703582e-06

# %%
plt.plot(loss_arr, "*-")

# %%
rr = model.nonlinear_fn(all_h[0,:,:])
lol = torch.matmul(rr.T.float(), torch.from_numpy(axes_orth.T).float())
plt.plot(lol[:int(0.7*750),0].detach().numpy(), lol[:int(0.7*750),1].detach().numpy())
plt.plot(lol[0,0].detach().numpy(), lol[0,1].detach().numpy(), "*")

#zoom in
plt.figure()
plt.plot(lol[int(0.7*750)-100:int(0.7*750),0].detach().numpy(), lol[int(0.7*750)-100:int(0.7*750),1].detach().numpy())

# %%
h_star_arr = np.stack(h_star_arr)
rr = model.nonlinear_fn(torch.from_numpy(h_star_arr))
lol = torch.matmul(rr.float(), torch.from_numpy(axes_orth.T).float())
plt.plot(lol[:int(0.7*750),0].detach().numpy(), lol[:int(0.7*750),1].detach().numpy())
plt.plot(lol[0,0].detach().numpy(), lol[0,1].detach().numpy(), "*")

# %%
proj_star_arr = []
for i in range(len(X)):
    print(i)
    h_star, r_star, final_loss, loss_arr, h_star_arr = find_fixed_point(X, all_h, model, i, time_idx=int(0.7 * 750))
    r_star = model.nonlinear_fn(h_star)

    proj_star = torch.matmul(r_star.float(), torch.from_numpy(axes_orth.T).float())
    proj_star_arr.append(proj_star)
# Out:
# 0
# Iter 0, loss = 8.932e-02
# Iter 100, loss = 8.872e-07
# 1
# Iter 0, loss = 1.065e-01
# Iter 100, loss = 4.394e-04
# Iter 200, loss = 4.927e-05
# Iter 300, loss = 1.417e-06
# Iter 400, loss = 5.349e-08
# 2
# Iter 0, loss = 1.632e-01
# Iter 100, loss = 2.846e-04
# Iter 200, loss = 5.404e-06
# Iter 300, loss = 2.793e-08
# 3
# Iter 0, loss = 9.545e-02
# Iter 100, loss = 4.633e-03
# Iter 200, loss = 3.527e-03
# Iter 300, loss = 2.689e-03
# Iter 400, loss = 2.059e-03
# Iter 500, loss = 1.561e-03
# Iter 600, loss = 1.160e-03
# Iter 700, loss = 7.987e-04
# Iter 800, loss = 5.133e-04
# Iter 900, loss = 3.017e-04
# 4
# Iter 0, loss = 8.636e-02
# Iter 100, loss = 7.098e-07
# 5
# Iter 0, loss = 1.990e-01
# Iter 100, loss = 3.223e-03
# Iter 200, loss = 1.400e-03
# Iter 300, loss = 4.021e-04
# Iter 400, loss = 6.969e-05
# Iter 500, loss = 7.283e-06
# Iter 600, loss = 5.441e-07
# Iter 700, loss = 9.073e-07
# 6
# Iter 0, loss = 1.627e-01
# Iter 100, loss = 2.218e-04
# Iter 200, loss = 4.346e-05
# Iter 300, loss = 8.643e-06
# Iter 400, loss = 8.198e-07
# Iter 500, loss = 2.665e-08
# 7
# Iter 0, loss = 1.583e-01
# Iter 100, loss = 1.031e-03
# Iter 200, loss = 3.422e-04
# Iter 300, loss = 8.640e-05
# Iter 400, loss = 1.664e-05
# Iter 500, loss = 2.421e-06
# Iter 600, loss = 2.582e-07
# Iter 700, loss = 2.280e-06
# Iter 800, loss = 3.251e-05
# Iter 900, loss = 1.042e-05
# 8
# Iter 0, loss = 8.503e-02
# Iter 100, loss = 5.034e-06
# 9
# Iter 0, loss = 6.786e-02
# Iter 100, loss = 7.785e-07
# 10
# Iter 0, loss = 1.003e-01
# Iter 100, loss = 9.746e-06
# 11
# Iter 0, loss = 1.057e-01
# Iter 100, loss = 3.319e-05
# Iter 200, loss = 4.333e-08
# 12
# Iter 0, loss = 1.032e-01
# Iter 100, loss = 6.383e-04
# Iter 200, loss = 1.025e-05
# 13
# Iter 0, loss = 7.258e-02
# Iter 100, loss = 6.686e-04
# Iter 200, loss = 2.140e-04
# Iter 300, loss = 5.325e-05
# Iter 400, loss = 1.075e-05
# Iter 500, loss = 1.742e-06
# Iter 600, loss = 6.132e-07
# Iter 700, loss = 6.898e-07
# Iter 800, loss = 1.273e-06
# Iter 900, loss = 3.300e-06
# 14
# Iter 0, loss = 1.199e-01
# Iter 100, loss = 4.567e-04
# Iter 200, loss = 1.569e-06
# 15
# Iter 0, loss = 1.013e-01
# Iter 100, loss = 3.111e-03
# Iter 200, loss = 3.085e-03
# Iter 300, loss = 3.044e-03
# Iter 400, loss = 2.969e-03
# Iter 500, loss = 2.822e-03
# Iter 600, loss = 2.548e-03
# Iter 700, loss = 1.991e-03
# Iter 800, loss = 1.101e-03
# Iter 900, loss = 3.092e-04
# 16
# Iter 0, loss = 1.480e-01
# Iter 100, loss = 1.271e-05
# Iter 200, loss = 1.702e-06
# Iter 300, loss = 2.442e-07
# Iter 400, loss = 2.194e-08
# 17
# Iter 0, loss = 9.302e-02
# Iter 100, loss = 6.285e-04
# Iter 200, loss = 4.172e-04
# Iter 300, loss = 2.497e-04
# Iter 400, loss = 1.373e-04
# Iter 500, loss = 7.034e-05
# Iter 600, loss = 3.388e-05
# Iter 700, loss = 3.908e-05
# Iter 800, loss = 8.240e-06
# Iter 900, loss = 3.630e-05
# 18
# Iter 0, loss = 1.111e-01
# Iter 100, loss = 2.483e-05
# Iter 200, loss = 2.703e-07
# 19
# Iter 0, loss = 6.881e-02
# Iter 100, loss = 1.269e-06
# 20
# Iter 0, loss = 1.247e-01
# Iter 100, loss = 3.211e-06
# 21
# Iter 0, loss = 9.655e-02
# Iter 100, loss = 4.287e-05
# 22
# Iter 0, loss = 1.294e-01
# Iter 100, loss = 4.114e-04
# Iter 200, loss = 1.890e-05
# Iter 300, loss = 3.695e-07
# 23
# Iter 0, loss = 1.012e-01
# Iter 100, loss = 1.189e-06
# 24
# Iter 0, loss = 1.210e-01
# Iter 100, loss = 2.804e-03
# Iter 200, loss = 1.294e-03
# Iter 300, loss = 5.167e-04
# Iter 400, loss = 1.824e-04
# Iter 500, loss = 5.707e-05
# Iter 600, loss = 1.572e-05
# Iter 700, loss = 3.821e-06
# Iter 800, loss = 1.836e-06
# Iter 900, loss = 4.175e-06
# 25
# Iter 0, loss = 1.246e-01
# Iter 100, loss = 1.387e-02
# Iter 200, loss = 1.182e-02
# Iter 300, loss = 9.948e-03
# Iter 400, loss = 8.278e-03
# Iter 500, loss = 6.704e-03
# Iter 600, loss = 5.147e-03
# Iter 700, loss = 3.587e-03
# Iter 800, loss = 2.129e-03
# Iter 900, loss = 9.854e-04
# 26
# Iter 0, loss = 1.702e-01
# Iter 100, loss = 3.462e-03
# Iter 200, loss = 1.889e-03
# Iter 300, loss = 8.130e-04
# Iter 400, loss = 2.716e-04
# Iter 500, loss = 7.034e-05
# Iter 600, loss = 1.409e-05
# Iter 700, loss = 2.761e-06
# Iter 800, loss = 8.581e-07
# Iter 900, loss = 2.860e-07
# 27
# Iter 0, loss = 9.091e-02
# Iter 100, loss = 4.482e-04
# Iter 200, loss = 1.518e-05
# Iter 300, loss = 5.944e-08
# 28
# Iter 0, loss = 1.045e-01
# Iter 100, loss = 6.120e-06
# 29
# Iter 0, loss = 1.270e-01
# Iter 100, loss = 1.154e-03
# Iter 200, loss = 8.745e-05
# Iter 300, loss = 3.619e-06
# Iter 400, loss = 6.948e-08
# 30
# Iter 0, loss = 7.843e-02
# Iter 100, loss = 3.842e-05
# Iter 200, loss = 3.915e-08
# 31
# Iter 0, loss = 2.052e-01
# Iter 100, loss = 5.349e-04
# Iter 200, loss = 1.178e-04
# Iter 300, loss = 2.298e-05
# Iter 400, loss = 4.116e-06
# Iter 500, loss = 5.826e-07
# Iter 600, loss = 2.210e-07
# 32
# Iter 0, loss = 1.547e-01
# Iter 100, loss = 1.348e-03
# Iter 200, loss = 1.669e-04
# Iter 300, loss = 1.201e-05
# Iter 400, loss = 6.298e-07
# Iter 500, loss = 2.235e-08
# Iter 600, loss = 7.010e-06
# Iter 700, loss = 5.815e-06
# Iter 800, loss = 6.935e-07
# Iter 900, loss = 4.673e-07
# 33
# Iter 0, loss = 7.919e-02
# Iter 100, loss = 2.568e-05
# Iter 200, loss = 4.956e-06
# Iter 300, loss = 5.341e-07
# Iter 400, loss = 3.247e-08
# 34
# Iter 0, loss = 9.562e-02
# Iter 100, loss = 2.181e-06
# Iter 200, loss = 1.074e-08
# 35
# Iter 0, loss = 9.776e-02
# Iter 100, loss = 1.204e-05
# 36
# Iter 0, loss = 9.757e-02
# Iter 100, loss = 3.690e-04
# Iter 200, loss = 5.782e-05
# Iter 300, loss = 4.596e-06
# Iter 400, loss = 1.894e-07
# 37
# Iter 0, loss = 1.086e-01
# Iter 100, loss = 2.152e-04
# Iter 200, loss = 9.190e-06
# Iter 300, loss = 8.329e-08
# 38
# Iter 0, loss = 1.425e-01
# Iter 100, loss = 9.091e-05
# Iter 200, loss = 2.699e-05
# Iter 300, loss = 6.154e-06
# Iter 400, loss = 8.318e-07
# Iter 500, loss = 1.085e-07
# Iter 600, loss = 2.595e-08
# Iter 700, loss = 3.922e-06
# Iter 800, loss = 1.548e-05
# Iter 900, loss = 1.179e-06
# 39
# Iter 0, loss = 6.601e-02
# Iter 100, loss = 7.327e-05
# Iter 200, loss = 7.433e-06
# Iter 300, loss = 3.996e-07
# Iter 400, loss = 1.034e-08
# 40
# Iter 0, loss = 1.554e-01
# Iter 100, loss = 8.994e-05
# Iter 200, loss = 1.700e-05
# Iter 300, loss = 1.753e-06
# Iter 400, loss = 9.860e-08
# 41
# Iter 0, loss = 1.111e-01
# Iter 100, loss = 9.581e-05
# 42
# Iter 0, loss = 1.558e-01
# Iter 100, loss = 1.159e-03
# Iter 200, loss = 4.542e-04
# Iter 300, loss = 1.215e-04
# Iter 400, loss = 2.224e-05
# Iter 500, loss = 3.147e-06
# Iter 600, loss = 2.593e-07
# Iter 700, loss = 2.246e-07
# 43
# Iter 0, loss = 9.928e-02
# Iter 100, loss = 2.444e-06
# 44
# Iter 0, loss = 1.475e-01
# Iter 100, loss = 4.167e-04
# Iter 200, loss = 3.127e-04
# Iter 300, loss = 2.310e-04
# Iter 400, loss = 1.626e-04
# Iter 500, loss = 1.101e-04
# Iter 600, loss = 7.207e-05
# Iter 700, loss = 4.573e-05
# Iter 800, loss = 2.815e-05
# Iter 900, loss = 1.778e-05
# 45
# Iter 0, loss = 1.285e-01
# Iter 100, loss = 1.589e-04
# Iter 200, loss = 2.078e-05
# Iter 300, loss = 1.415e-06
# Iter 400, loss = 4.953e-08
# 46
# Iter 0, loss = 1.097e-01
# Iter 100, loss = 4.893e-04
# Iter 200, loss = 2.219e-04
# Iter 300, loss = 8.525e-05
# Iter 400, loss = 2.750e-05
# Iter 500, loss = 9.135e-06
# Iter 600, loss = 1.733e-06
# Iter 700, loss = 3.655e-07
# Iter 800, loss = 5.236e-07
# Iter 900, loss = 1.072e-06
# 47
# Iter 0, loss = 1.222e-01
# Iter 100, loss = 4.449e-04
# Iter 200, loss = 1.171e-05
# Iter 300, loss = 7.255e-08
# 48
# Iter 0, loss = 1.314e-01
# Iter 100, loss = 1.564e-04
# Iter 200, loss = 1.076e-05
# Iter 300, loss = 3.693e-07
# Iter 400, loss = 3.468e-07
# 49
# Iter 0, loss = 7.746e-02
# Iter 100, loss = 4.511e-04
# Iter 200, loss = 1.191e-04
# Iter 300, loss = 2.783e-05
# Iter 400, loss = 5.860e-06
# Iter 500, loss = 1.463e-06
# Iter 600, loss = 2.833e-06
# Iter 700, loss = 1.663e-06
# Iter 800, loss = 1.057e-05
# 50
# Iter 0, loss = 9.739e-02
# Iter 100, loss = 2.399e-03
# Iter 200, loss = 1.673e-04
# Iter 300, loss = 1.965e-06
# 51
# Iter 0, loss = 1.392e-01
# Iter 100, loss = 1.764e-05
# 52
# Iter 0, loss = 1.821e-01
# Iter 100, loss = 2.359e-03
# Iter 200, loss = 1.017e-03
# Iter 300, loss = 2.845e-04
# Iter 400, loss = 5.096e-05
# Iter 500, loss = 5.961e-06
# Iter 600, loss = 4.696e-07
# Iter 700, loss = 1.058e-07
# 53
# Iter 0, loss = 1.552e-01
# Iter 100, loss = 7.883e-04
# Iter 200, loss = 2.701e-04
# Iter 300, loss = 7.551e-05
# Iter 400, loss = 1.679e-05
# Iter 500, loss = 3.207e-06
# Iter 600, loss = 4.150e-07
# Iter 700, loss = 7.055e-07
# 54
# Iter 0, loss = 8.671e-02
# Iter 100, loss = 2.493e-05
# 55
# Iter 0, loss = 1.152e-01
# Iter 100, loss = 4.676e-06
# 56
# Iter 0, loss = 9.854e-02
# Iter 100, loss = 1.345e-04
# Iter 200, loss = 1.261e-05
# Iter 300, loss = 4.727e-07
# 57
# Iter 0, loss = 9.270e-02
# Iter 100, loss = 3.651e-03
# Iter 200, loss = 3.504e-03
# Iter 300, loss = 3.297e-03
# Iter 400, loss = 3.014e-03
# Iter 500, loss = 2.629e-03
# Iter 600, loss = 2.109e-03
# Iter 700, loss = 1.458e-03
# Iter 800, loss = 7.798e-04
# Iter 900, loss = 3.079e-04
# 58
# Iter 0, loss = 7.101e-02
# Iter 100, loss = 7.260e-07
# 59
# Iter 0, loss = 7.648e-02
# Iter 100, loss = 8.135e-05
# Iter 200, loss = 6.258e-07
# 60
# Iter 0, loss = 1.063e-01
# Iter 100, loss = 1.785e-06
# 61
# Iter 0, loss = 1.033e-01
# Iter 100, loss = 5.514e-04
# Iter 200, loss = 3.643e-06
# 62
# Iter 0, loss = 1.339e-01
# Iter 100, loss = 6.507e-05
# Iter 200, loss = 3.375e-06
# Iter 300, loss = 9.954e-08
# 63
# Iter 0, loss = 1.506e-01
# Iter 100, loss = 3.084e-05
# 64
# Iter 0, loss = 1.047e-01
# Iter 100, loss = 1.022e-03
# Iter 200, loss = 1.601e-04
# Iter 300, loss = 6.372e-06
# Iter 400, loss = 6.933e-08
# 65
# Iter 0, loss = 1.161e-01
# Iter 100, loss = 1.450e-04
# Iter 200, loss = 5.777e-06
# Iter 300, loss = 6.175e-08
# 66
# Iter 0, loss = 1.009e-01
# Iter 100, loss = 1.185e-05
# 67
# Iter 0, loss = 1.912e-01
# Iter 100, loss = 6.066e-03
# Iter 200, loss = 8.820e-04
# Iter 300, loss = 9.682e-05
# Iter 400, loss = 7.960e-06
# Iter 500, loss = 8.735e-06
# Iter 600, loss = 1.355e-08
# 68
# Iter 0, loss = 1.111e-01
# Iter 100, loss = 5.310e-04
# Iter 200, loss = 1.567e-04
# Iter 300, loss = 3.498e-05
# Iter 400, loss = 6.738e-06
# Iter 500, loss = 1.282e-06
# Iter 600, loss = 5.782e-05
# Iter 700, loss = 7.023e-05
# Iter 800, loss = 5.505e-06
# 69
# Iter 0, loss = 1.541e-01
# Iter 100, loss = 1.478e-04
# Iter 200, loss = 3.316e-05
# Iter 300, loss = 5.926e-06
# Iter 400, loss = 8.007e-07
# Iter 500, loss = 7.914e-08
# 70
# Iter 0, loss = 1.629e-01
# Iter 100, loss = 2.295e-03
# Iter 200, loss = 1.190e-03
# Iter 300, loss = 5.267e-04
# Iter 400, loss = 1.742e-04
# Iter 500, loss = 4.274e-05
# Iter 600, loss = 8.317e-06
# Iter 700, loss = 1.218e-06
# Iter 800, loss = 1.304e-07
# Iter 900, loss = 8.719e-08
# 71
# Iter 0, loss = 7.674e-02
# Iter 100, loss = 6.269e-04
# Iter 200, loss = 5.324e-04
# Iter 300, loss = 4.227e-04
# Iter 400, loss = 3.109e-04
# Iter 500, loss = 2.087e-04
# Iter 600, loss = 1.254e-04
# Iter 700, loss = 6.605e-05
# Iter 800, loss = 3.001e-05
# Iter 900, loss = 1.174e-05
# 72
# Iter 0, loss = 8.839e-02
# Iter 100, loss = 3.858e-04
# Iter 200, loss = 5.221e-05
# Iter 300, loss = 2.692e-06
# Iter 400, loss = 5.087e-07
# 73
# Iter 0, loss = 8.687e-02
# Iter 100, loss = 3.653e-04
# Iter 200, loss = 6.413e-07
# 74
# Iter 0, loss = 8.701e-02
# Iter 100, loss = 4.459e-05
# Iter 200, loss = 5.575e-07
# 75
# Iter 0, loss = 1.054e-01
# Iter 100, loss = 1.092e-03
# Iter 200, loss = 3.933e-04
# Iter 300, loss = 8.759e-05
# Iter 400, loss = 1.217e-05
# Iter 500, loss = 1.086e-06
# Iter 600, loss = 6.366e-08
# 76
# Iter 0, loss = 1.387e-01
# Iter 100, loss = 3.682e-03
# Iter 200, loss = 3.400e-04
# Iter 300, loss = 5.236e-06
# Iter 400, loss = 1.418e-08
# 77
# Iter 0, loss = 1.104e-01
# Iter 100, loss = 1.533e-06
# 78
# Iter 0, loss = 1.343e-01
# Iter 100, loss = 2.348e-03
# Iter 200, loss = 1.096e-04
# Iter 300, loss = 9.733e-07
# 79
# Iter 0, loss = 1.369e-01
# Iter 100, loss = 2.127e-05
# Iter 200, loss = 6.084e-07
# 80
# Iter 0, loss = 1.237e-01
# Iter 100, loss = 1.222e-03
# Iter 200, loss = 4.494e-04
# Iter 300, loss = 1.041e-04
# Iter 400, loss = 1.525e-05
# Iter 500, loss = 4.714e-06
# Iter 600, loss = 9.160e-08
# Iter 700, loss = 5.469e-08
# 81
# Iter 0, loss = 7.405e-02
# Iter 100, loss = 2.589e-06
# 82
# Iter 0, loss = 1.349e-01
# Iter 100, loss = 9.603e-04
# Iter 200, loss = 7.407e-05
# Iter 300, loss = 2.717e-06
# Iter 400, loss = 4.777e-08
# 83
# Iter 0, loss = 1.753e-01
# Iter 100, loss = 4.707e-03
# Iter 200, loss = 2.405e-03
# Iter 300, loss = 8.520e-04
# Iter 400, loss = 2.009e-04
# Iter 500, loss = 3.137e-05
# Iter 600, loss = 3.338e-06
# Iter 700, loss = 4.306e-07
# Iter 800, loss = 1.327e-08
# 84
# Iter 0, loss = 1.558e-01
# Iter 100, loss = 8.800e-03
# Iter 200, loss = 2.657e-03
# Iter 300, loss = 4.260e-04
# Iter 400, loss = 3.390e-05
# Iter 500, loss = 3.825e-06
# Iter 600, loss = 3.603e-08
# 85
# Iter 0, loss = 7.582e-02
# Iter 100, loss = 1.368e-05
# Iter 200, loss = 3.063e-06
# Iter 300, loss = 4.428e-07
# Iter 400, loss = 4.005e-08
# 86
# Iter 0, loss = 1.906e-01
# Iter 100, loss = 2.903e-03
# Iter 200, loss = 6.182e-04
# Iter 300, loss = 9.716e-05
# Iter 400, loss = 1.140e-05
# Iter 500, loss = 9.715e-07
# Iter 600, loss = 5.827e-08
# 87
# Iter 0, loss = 1.164e-01
# Iter 100, loss = 3.215e-04
# Iter 200, loss = 6.947e-05
# Iter 300, loss = 7.710e-06
# Iter 400, loss = 4.557e-07
# Iter 500, loss = 1.477e-08
# 88
# Iter 0, loss = 1.201e-01
# Iter 100, loss = 1.494e-04
# Iter 200, loss = 1.333e-05
# Iter 300, loss = 4.003e-07
# 89
# Iter 0, loss = 9.729e-02
# Iter 100, loss = 5.632e-04
# Iter 200, loss = 4.894e-04
# Iter 300, loss = 4.049e-04
# Iter 400, loss = 3.196e-04
# Iter 500, loss = 2.379e-04
# Iter 600, loss = 1.675e-04
# Iter 700, loss = 1.106e-04
# Iter 800, loss = 6.823e-05
# Iter 900, loss = 4.307e-05
# 90
# Iter 0, loss = 9.828e-02
# Iter 100, loss = 6.873e-05
# Iter 200, loss = 2.599e-08
# 91
# Iter 0, loss = 1.049e-01
# Iter 100, loss = 9.449e-05
# Iter 200, loss = 3.606e-06
# Iter 300, loss = 4.312e-08
# 92
# Iter 0, loss = 1.354e-01
# Iter 100, loss = 9.899e-04
# Iter 200, loss = 2.837e-05
# Iter 300, loss = 1.293e-07
# 93
# Iter 0, loss = 1.225e-01
# Iter 100, loss = 2.720e-04
# Iter 200, loss = 3.256e-06
# Iter 300, loss = 1.107e-07
# 94
# Iter 0, loss = 9.235e-02
# Iter 100, loss = 3.664e-06
# 95
# Iter 0, loss = 7.518e-02
# Iter 100, loss = 1.040e-06
# 96
# Iter 0, loss = 1.216e-01
# Iter 100, loss = 6.312e-04
# Iter 200, loss = 4.335e-04
# Iter 300, loss = 2.706e-04
# Iter 400, loss = 1.481e-04
# Iter 500, loss = 7.085e-05
# Iter 600, loss = 2.950e-05
# Iter 700, loss = 1.128e-05
# Iter 800, loss = 3.632e-06
# Iter 900, loss = 9.589e-07
# 97
# Iter 0, loss = 1.128e-01
# Iter 100, loss = 7.411e-03
# Iter 200, loss = 2.050e-03
# Iter 300, loss = 2.169e-04
# Iter 400, loss = 7.968e-06
# Iter 500, loss = 1.312e-07
# Iter 600, loss = 1.747e-06
# 98
# Iter 0, loss = 1.149e-01
# Iter 100, loss = 1.376e-03
# Iter 200, loss = 9.269e-04
# Iter 300, loss = 5.123e-04
# Iter 400, loss = 2.268e-04
# Iter 500, loss = 7.963e-05
# Iter 600, loss = 2.229e-05
# Iter 700, loss = 4.984e-06
# Iter 800, loss = 9.431e-07
# Iter 900, loss = 2.129e-06
# 99
# Iter 0, loss = 7.907e-02
# Iter 100, loss = 8.602e-07
# 100
# Iter 0, loss = 8.513e-02
# Iter 100, loss = 6.698e-06
# Iter 200, loss = 2.460e-07
# 101
# Iter 0, loss = 8.039e-02
# Iter 100, loss = 9.228e-07
# 102
# Iter 0, loss = 1.690e-01
# Iter 100, loss = 1.246e-03
# Iter 200, loss = 6.116e-04
# Iter 300, loss = 2.562e-04
# Iter 400, loss = 9.530e-05
# Iter 500, loss = 3.181e-05
# Iter 600, loss = 9.507e-06
# Iter 700, loss = 7.270e-06
# Iter 800, loss = 5.986e-07
# Iter 900, loss = 1.270e-07
# 103
# Iter 0, loss = 5.820e-02
# Iter 100, loss = 6.827e-07
# 104
# Iter 0, loss = 1.283e-01
# Iter 100, loss = 1.360e-04
# Iter 200, loss = 3.183e-05
# Iter 300, loss = 3.799e-06
# Iter 400, loss = 2.383e-07
# 105
# Iter 0, loss = 5.577e-02
# Iter 100, loss = 2.039e-05
# 106
# Iter 0, loss = 1.354e-01
# Iter 100, loss = 1.849e-06
# 107
# Iter 0, loss = 1.148e-01
# Iter 100, loss = 1.476e-03
# Iter 200, loss = 7.096e-05
# Iter 300, loss = 7.109e-07
# 108
# Iter 0, loss = 1.408e-01
# Iter 100, loss = 3.770e-04
# Iter 200, loss = 8.450e-05
# Iter 300, loss = 1.870e-05
# Iter 400, loss = 3.109e-06
# Iter 500, loss = 3.859e-07
# Iter 600, loss = 8.020e-06
# 109
# Iter 0, loss = 1.280e-01
# Iter 100, loss = 9.277e-05
# Iter 200, loss = 1.969e-05
# Iter 300, loss = 2.576e-06
# Iter 400, loss = 2.109e-07
# Iter 500, loss = 1.071e-08
# 110
# Iter 0, loss = 7.534e-02
# Iter 100, loss = 5.420e-06
# 111
# Iter 0, loss = 2.111e-01
# Iter 100, loss = 1.377e-03
# Iter 200, loss = 8.584e-04
# Iter 300, loss = 4.765e-04
# Iter 400, loss = 2.224e-04
# Iter 500, loss = 8.759e-05
# Iter 600, loss = 2.926e-05
# Iter 700, loss = 8.331e-06
# Iter 800, loss = 7.061e-05
# Iter 900, loss = 4.261e-07
# 112
# Iter 0, loss = 1.935e-01
# Iter 100, loss = 4.927e-04
# Iter 200, loss = 2.260e-05
# Iter 300, loss = 4.220e-07
# 113
# Iter 0, loss = 1.118e-01
# Iter 100, loss = 1.208e-03
# Iter 200, loss = 3.408e-06
# 114
# Iter 0, loss = 1.094e-01
# Iter 100, loss = 8.761e-06
# Iter 200, loss = 9.344e-08
# 115
# Iter 0, loss = 1.254e-01
# Iter 100, loss = 7.810e-05
# Iter 200, loss = 1.323e-08
# 116
# Iter 0, loss = 1.195e-01
# Iter 100, loss = 2.864e-04
# Iter 200, loss = 1.704e-04
# Iter 300, loss = 9.105e-05
# Iter 400, loss = 4.384e-05
# Iter 500, loss = 1.926e-05
# Iter 600, loss = 1.015e-05
# Iter 700, loss = 2.871e-06
# Iter 800, loss = 9.962e-07
# Iter 900, loss = 2.663e-06
# 117
# Iter 0, loss = 9.992e-02
# Iter 100, loss = 5.205e-04
# Iter 200, loss = 6.387e-06
# 118
# Iter 0, loss = 8.937e-02
# Iter 100, loss = 3.463e-05
# Iter 200, loss = 1.164e-05
# Iter 300, loss = 3.078e-06
# Iter 400, loss = 5.860e-07
# Iter 500, loss = 6.895e-07
# Iter 600, loss = 4.463e-07
# Iter 700, loss = 6.693e-08
# 119
# Iter 0, loss = 1.172e-01
# Iter 100, loss = 2.108e-03
# Iter 200, loss = 1.900e-03
# Iter 300, loss = 1.655e-03
# Iter 400, loss = 1.390e-03
# Iter 500, loss = 1.119e-03
# Iter 600, loss = 8.528e-04
# Iter 700, loss = 5.997e-04
# Iter 800, loss = 3.788e-04
# Iter 900, loss = 2.082e-04
# 120
# Iter 0, loss = 8.022e-02
# Iter 100, loss = 4.771e-06
# 121
# Iter 0, loss = 2.027e-01
# Iter 100, loss = 1.768e-03
# Iter 200, loss = 4.975e-04
# Iter 300, loss = 8.253e-05
# Iter 400, loss = 7.912e-06
# Iter 500, loss = 4.613e-07
# Iter 600, loss = 1.687e-08
# 122
# Iter 0, loss = 9.323e-02
# Iter 100, loss = 3.613e-06
# 123
# Iter 0, loss = 9.129e-02
# Iter 100, loss = 1.729e-06
# Iter 200, loss = 1.645e-08
# 124
# Iter 0, loss = 9.889e-02
# Iter 100, loss = 6.588e-05
# Iter 200, loss = 1.354e-07
# 125
# Iter 0, loss = 9.014e-02
# Iter 100, loss = 1.225e-06
# 126
# Iter 0, loss = 8.143e-02
# Iter 100, loss = 9.707e-07
# 127
# Iter 0, loss = 1.402e-01
# Iter 100, loss = 1.262e-03
# Iter 200, loss = 3.500e-04
# Iter 300, loss = 7.072e-05
# Iter 400, loss = 1.050e-05
# Iter 500, loss = 1.156e-06
# Iter 600, loss = 1.484e-07
# Iter 700, loss = 1.911e-08
# 128
# Iter 0, loss = 1.238e-01
# Iter 100, loss = 1.316e-03
# Iter 200, loss = 1.045e-03
# Iter 300, loss = 7.984e-04
# Iter 400, loss = 5.950e-04
# Iter 500, loss = 4.365e-04
# Iter 600, loss = 3.173e-04
# Iter 700, loss = 2.263e-04
# Iter 800, loss = 1.597e-04
# Iter 900, loss = 1.113e-04
# 129
# Iter 0, loss = 1.270e-01
# Iter 100, loss = 2.170e-03
# Iter 200, loss = 6.205e-04
# Iter 300, loss = 6.058e-05
# Iter 400, loss = 1.965e-06
# Iter 500, loss = 3.415e-08
# 130
# Iter 0, loss = 9.201e-02
# Iter 100, loss = 4.662e-05
# Iter 200, loss = 3.536e-05
# Iter 300, loss = 3.254e-05
# Iter 400, loss = 1.775e-05
# Iter 500, loss = 1.163e-05
# Iter 600, loss = 8.193e-06
# Iter 700, loss = 2.566e-05
# Iter 800, loss = 4.209e-06
# Iter 900, loss = 6.952e-05
# 131
# Iter 0, loss = 8.473e-02
# Iter 100, loss = 7.697e-04
# Iter 200, loss = 1.520e-04
# Iter 300, loss = 2.624e-05
# Iter 400, loss = 3.787e-06
# Iter 500, loss = 6.025e-07
# Iter 600, loss = 2.529e-06
# 132
# Iter 0, loss = 8.224e-02
# Iter 100, loss = 4.781e-05
# Iter 200, loss = 4.402e-07
# 133
# Iter 0, loss = 1.469e-01
# Iter 100, loss = 8.366e-05
# Iter 200, loss = 6.134e-06
# Iter 300, loss = 1.795e-07
# 134
# Iter 0, loss = 7.723e-02
# Iter 100, loss = 5.332e-05
# Iter 200, loss = 1.286e-07
# 135
# Iter 0, loss = 9.338e-02
# Iter 100, loss = 2.976e-04
# Iter 200, loss = 3.305e-08
# 136
# Iter 0, loss = 6.751e-02
# Iter 100, loss = 2.281e-04
# Iter 200, loss = 1.680e-04
# Iter 300, loss = 1.123e-04
# Iter 400, loss = 6.866e-05
# Iter 500, loss = 3.860e-05
# Iter 600, loss = 2.076e-05
# Iter 700, loss = 1.081e-05
# Iter 800, loss = 4.875e-05
# Iter 900, loss = 8.890e-06
# 137
# Iter 0, loss = 1.496e-01
# Iter 100, loss = 1.164e-03
# Iter 200, loss = 5.634e-04
# Iter 300, loss = 2.206e-04
# Iter 400, loss = 6.376e-05
# Iter 500, loss = 1.355e-05
# Iter 600, loss = 2.142e-06
# Iter 700, loss = 2.562e-07
# Iter 800, loss = 2.337e-08
# 138
# Iter 0, loss = 1.757e-01
# Iter 100, loss = 8.189e-05
# Iter 200, loss = 8.886e-06
# Iter 300, loss = 1.281e-06
# Iter 400, loss = 1.191e-07
# 139
# Iter 0, loss = 1.579e-01
# Iter 100, loss = 7.018e-03
# Iter 200, loss = 3.962e-03
# Iter 300, loss = 2.716e-03
# Iter 400, loss = 2.147e-03
# Iter 500, loss = 1.871e-03
# Iter 600, loss = 1.712e-03
# Iter 700, loss = 1.638e-03
# Iter 800, loss = 1.590e-03
# Iter 900, loss = 1.569e-03
# 140
# Iter 0, loss = 1.580e-01
# Iter 100, loss = 1.116e-04
# Iter 200, loss = 3.357e-05
# Iter 300, loss = 6.524e-06
# Iter 400, loss = 2.588e-06
# Iter 500, loss = 6.916e-08
# Iter 600, loss = 3.041e-07
# 141
# Iter 0, loss = 8.391e-02
# Iter 100, loss = 1.888e-04
# Iter 200, loss = 4.821e-05
# Iter 300, loss = 1.268e-05
# Iter 400, loss = 2.627e-06
# Iter 500, loss = 5.986e-07
# Iter 600, loss = 4.025e-06
# Iter 700, loss = 5.364e-06
# Iter 800, loss = 3.972e-05
# 142
# Iter 0, loss = 5.754e-02
# Iter 100, loss = 1.099e-06
# 143
# Iter 0, loss = 9.799e-02
# Iter 100, loss = 1.033e-04
# Iter 200, loss = 1.423e-06
# 144
# Iter 0, loss = 7.131e-02
# Iter 100, loss = 1.996e-06
# 145
# Iter 0, loss = 1.400e-01
# Iter 100, loss = 1.706e-03
# Iter 200, loss = 6.627e-04
# Iter 300, loss = 2.212e-04
# Iter 400, loss = 6.266e-05
# Iter 500, loss = 1.494e-05
# Iter 600, loss = 5.874e-06
# Iter 700, loss = 1.078e-06
# Iter 800, loss = 5.814e-06
# Iter 900, loss = 3.096e-08
# 146
# Iter 0, loss = 1.064e-01
# Iter 100, loss = 1.108e-06
# 147
# Iter 0, loss = 1.112e-01
# Iter 100, loss = 1.043e-04
# Iter 200, loss = 3.410e-06
# Iter 300, loss = 2.681e-08
# 148
# Iter 0, loss = 9.115e-02
# Iter 100, loss = 2.551e-05
# Iter 200, loss = 1.845e-05
# Iter 300, loss = 1.249e-05
# Iter 400, loss = 7.682e-06
# Iter 500, loss = 9.237e-06
# Iter 600, loss = 2.203e-06
# Iter 700, loss = 1.040e-06
# Iter 800, loss = 5.111e-07
# Iter 900, loss = 2.442e-04
# 149
# Iter 0, loss = 9.287e-02
# Iter 100, loss = 1.345e-06
# 150
# Iter 0, loss = 8.227e-02
# Iter 100, loss = 2.968e-05
# Iter 200, loss = 1.234e-06
# Iter 300, loss = 1.136e-08
# 151
# Iter 0, loss = 2.175e-01
# Iter 100, loss = 4.679e-04
# Iter 200, loss = 3.532e-05
# Iter 300, loss = 2.353e-05
# Iter 400, loss = 1.666e-05
# Iter 500, loss = 1.101e-05
# Iter 600, loss = 4.024e-05
# Iter 700, loss = 3.887e-06
# Iter 800, loss = 2.716e-06
# Iter 900, loss = 3.409e-06
# 152
# Iter 0, loss = 1.659e-01
# Iter 100, loss = 4.218e-04
# Iter 200, loss = 1.678e-04
# Iter 300, loss = 5.607e-05
# Iter 400, loss = 1.496e-05
# Iter 500, loss = 4.388e-06
# Iter 600, loss = 2.399e-06
# Iter 700, loss = 1.375e-07
# Iter 800, loss = 2.048e-07
# Iter 900, loss = 7.341e-08
# 153
# Iter 0, loss = 2.483e-01
# Iter 100, loss = 9.490e-03
# Iter 200, loss = 2.874e-03
# Iter 300, loss = 7.855e-04
# Iter 400, loss = 1.977e-04
# Iter 500, loss = 4.490e-05
# Iter 600, loss = 8.937e-06
# Iter 700, loss = 1.515e-06
# Iter 800, loss = 2.140e-07
# Iter 900, loss = 2.490e-08
# 154
# Iter 0, loss = 1.023e-01
# Iter 100, loss = 6.728e-05
# Iter 200, loss = 1.021e-07
# 155
# Iter 0, loss = 1.674e-01
# Iter 100, loss = 9.040e-04
# Iter 200, loss = 5.216e-04
# Iter 300, loss = 2.708e-04
# Iter 400, loss = 1.253e-04
# Iter 500, loss = 5.220e-05
# Iter 600, loss = 1.966e-05
# Iter 700, loss = 6.676e-06
# Iter 800, loss = 2.037e-06
# Iter 900, loss = 5.558e-07
# 156
# Iter 0, loss = 9.768e-02
# Iter 100, loss = 1.666e-04
# Iter 200, loss = 1.496e-05
# Iter 300, loss = 6.831e-07
# Iter 400, loss = 1.480e-08
# 157
# Iter 0, loss = 8.253e-02
# Iter 100, loss = 4.205e-03
# Iter 200, loss = 3.560e-03
# Iter 300, loss = 2.851e-03
# Iter 400, loss = 2.131e-03
# Iter 500, loss = 1.429e-03
# Iter 600, loss = 8.019e-04
# Iter 700, loss = 3.358e-04
# Iter 800, loss = 9.285e-05
# Iter 900, loss = 1.693e-05
# 158
# Iter 0, loss = 1.037e-01
# Iter 100, loss = 3.472e-04
# Iter 200, loss = 1.485e-07
# 159
# Iter 0, loss = 1.505e-01
# Iter 100, loss = 4.962e-03
# Iter 200, loss = 2.965e-04
# Iter 300, loss = 4.973e-06
# Iter 400, loss = 2.306e-08
# 160
# Iter 0, loss = 8.493e-02
# Iter 100, loss = 3.443e-04
# Iter 200, loss = 1.232e-05
# Iter 300, loss = 1.248e-07
# 161
# Iter 0, loss = 9.308e-02
# Iter 100, loss = 1.335e-04
# Iter 200, loss = 1.032e-04
# Iter 300, loss = 7.519e-05
# Iter 400, loss = 5.209e-05
# Iter 500, loss = 3.461e-05
# Iter 600, loss = 2.470e-05
# Iter 700, loss = 1.680e-05
# Iter 800, loss = 3.789e-05
# Iter 900, loss = 5.091e-06
# 162
# Iter 0, loss = 1.032e-01
# Iter 100, loss = 1.225e-04
# 163
# Iter 0, loss = 1.994e-01
# Iter 100, loss = 1.070e-03
# Iter 200, loss = 2.247e-04
# Iter 300, loss = 5.977e-05
# Iter 400, loss = 1.137e-05
# Iter 500, loss = 1.774e-06
# Iter 600, loss = 1.577e-07
# Iter 700, loss = 5.835e-08
# 164
# Iter 0, loss = 1.377e-01
# Iter 100, loss = 2.997e-04
# Iter 200, loss = 1.074e-05
# Iter 300, loss = 1.181e-07
# 165
# Iter 0, loss = 7.352e-02
# Iter 100, loss = 8.898e-07
# 166
# Iter 0, loss = 1.530e-01
# Iter 100, loss = 1.575e-03
# Iter 200, loss = 8.765e-05
# Iter 300, loss = 7.870e-07
# 167
# Iter 0, loss = 8.850e-02
# Iter 100, loss = 2.974e-05
# Iter 200, loss = 1.691e-06
# Iter 300, loss = 7.416e-08
# 168
# Iter 0, loss = 1.148e-01
# Iter 100, loss = 3.689e-04
# Iter 200, loss = 2.324e-06
# 169
# Iter 0, loss = 1.012e-01
# Iter 100, loss = 3.012e-05
# Iter 200, loss = 5.140e-07
# 170
# Iter 0, loss = 1.083e-01
# Iter 100, loss = 2.224e-04
# Iter 200, loss = 1.244e-06
# 171
# Iter 0, loss = 9.150e-02
# Iter 100, loss = 1.449e-03
# Iter 200, loss = 1.125e-03
# Iter 300, loss = 8.355e-04
# Iter 400, loss = 6.049e-04
# Iter 500, loss = 4.304e-04
# Iter 600, loss = 3.040e-04
# Iter 700, loss = 2.293e-04
# Iter 800, loss = 1.410e-04
# Iter 900, loss = 9.495e-05
# 172
# Iter 0, loss = 1.586e-01
# Iter 100, loss = 2.959e-03
# Iter 200, loss = 2.414e-04
# Iter 300, loss = 8.365e-06
# Iter 400, loss = 1.341e-07
# 173
# Iter 0, loss = 8.557e-02
# Iter 100, loss = 1.000e-06
# 174
# Iter 0, loss = 1.005e-01
# Iter 100, loss = 5.126e-04
# Iter 200, loss = 5.718e-05
# Iter 300, loss = 3.219e-06
# Iter 400, loss = 1.314e-06
# 175
# Iter 0, loss = 8.134e-02
# Iter 100, loss = 8.816e-06
# Iter 200, loss = 3.496e-07
# 176
# Iter 0, loss = 8.717e-02
# Iter 100, loss = 1.813e-04
# Iter 200, loss = 3.239e-05
# Iter 300, loss = 3.758e-06
# Iter 400, loss = 2.848e-07
# Iter 500, loss = 2.892e-08
# 177
# Iter 0, loss = 1.192e-01
# Iter 100, loss = 2.736e-04
# Iter 200, loss = 2.828e-05
# Iter 300, loss = 1.397e-06
# Iter 400, loss = 3.234e-08
# 178
# Iter 0, loss = 1.163e-01
# Iter 100, loss = 1.343e-03
# Iter 200, loss = 1.843e-04
# Iter 300, loss = 9.824e-06
# Iter 400, loss = 2.286e-07
# 179
# Iter 0, loss = 1.011e-01
# Iter 100, loss = 2.465e-05
# Iter 200, loss = 2.386e-07
# 180
# Iter 0, loss = 1.103e-01
# Iter 100, loss = 3.217e-03
# Iter 200, loss = 1.011e-03
# Iter 300, loss = 2.824e-04
# Iter 400, loss = 7.219e-05
# Iter 500, loss = 1.657e-05
# Iter 600, loss = 3.342e-05
# Iter 700, loss = 5.854e-07
# Iter 800, loss = 1.175e-07
# Iter 900, loss = 1.248e-07
# 181
# Iter 0, loss = 1.241e-01
# Iter 100, loss = 1.043e-03
# Iter 200, loss = 7.376e-05
# Iter 300, loss = 8.264e-07
# 182
# Iter 0, loss = 8.617e-02
# Iter 100, loss = 1.703e-04
# Iter 200, loss = 1.040e-05
# Iter 300, loss = 2.753e-07
# 183
# Iter 0, loss = 9.509e-02
# Iter 100, loss = 8.923e-07
# 184
# Iter 0, loss = 1.082e-01
# Iter 100, loss = 6.705e-06
# Iter 200, loss = 2.016e-08
# 185
# Iter 0, loss = 2.015e-01
# Iter 100, loss = 1.305e-03
# Iter 200, loss = 8.021e-04
# Iter 300, loss = 4.245e-04
# Iter 400, loss = 1.929e-04
# Iter 500, loss = 7.466e-05
# Iter 600, loss = 2.447e-05
# Iter 700, loss = 6.790e-06
# Iter 800, loss = 2.688e-06
# Iter 900, loss = 2.277e-05
# 186
# Iter 0, loss = 9.569e-02
# Iter 100, loss = 4.738e-06
# Iter 200, loss = 6.372e-07
# Iter 300, loss = 6.354e-08
# 187
# Iter 0, loss = 1.013e-01
# Iter 100, loss = 2.701e-06
# 188
# Iter 0, loss = 9.825e-02
# Iter 100, loss = 3.138e-04
# Iter 200, loss = 2.076e-06
# 189
# Iter 0, loss = 9.576e-02
# Iter 100, loss = 3.669e-03
# Iter 200, loss = 1.212e-04
# Iter 300, loss = 2.877e-08
# 190
# Iter 0, loss = 1.479e-01
# Iter 100, loss = 8.714e-04
# Iter 200, loss = 9.280e-05
# Iter 300, loss = 5.117e-06
# Iter 400, loss = 1.538e-07
# 191
# Iter 0, loss = 2.124e-01
# Iter 100, loss = 2.824e-03
# Iter 200, loss = 5.828e-04
# Iter 300, loss = 9.003e-05
# Iter 400, loss = 9.927e-06
# Iter 500, loss = 7.679e-07
# Iter 600, loss = 1.822e-07
# 192
# Iter 0, loss = 1.020e-01
# Iter 100, loss = 3.035e-05
# 193
# Iter 0, loss = 8.631e-02
# Iter 100, loss = 4.079e-04
# Iter 200, loss = 7.626e-06
# Iter 300, loss = 3.324e-08
# 194
# Iter 0, loss = 1.110e-01
# Iter 100, loss = 1.849e-03
# Iter 200, loss = 7.377e-04
# Iter 300, loss = 2.484e-04
# Iter 400, loss = 6.817e-05
# Iter 500, loss = 1.617e-05
# Iter 600, loss = 3.299e-06
# Iter 700, loss = 1.338e-06
# Iter 800, loss = 7.975e-08
# Iter 900, loss = 3.951e-08
# 195
# Iter 0, loss = 9.859e-02
# Iter 100, loss = 1.104e-06
# 196
# Iter 0, loss = 1.082e-01
# Iter 100, loss = 4.554e-05
# Iter 200, loss = 4.947e-06
# Iter 300, loss = 2.828e-07
# Iter 400, loss = 3.143e-08
# 197
# Iter 0, loss = 9.704e-02
# Iter 100, loss = 8.596e-04
# Iter 200, loss = 2.399e-04
# Iter 300, loss = 5.736e-05
# Iter 400, loss = 1.198e-05
# Iter 500, loss = 2.136e-06
# Iter 600, loss = 3.926e-07
# Iter 700, loss = 1.013e-07
# 198
# Iter 0, loss = 2.519e-01
# Iter 100, loss = 3.504e-03
# Iter 200, loss = 7.323e-04
# Iter 300, loss = 7.485e-05
# Iter 400, loss = 3.835e-06
# Iter 500, loss = 1.013e-07
# 199
# Iter 0, loss = 1.315e-01
# Iter 100, loss = 1.723e-04
# Iter 200, loss = 9.556e-06
# Iter 300, loss = 2.779e-07
# 200
# Iter 0, loss = 8.351e-02
# Iter 100, loss = 2.341e-03
# Iter 200, loss = 1.174e-04
# Iter 300, loss = 1.142e-06
# 201
# Iter 0, loss = 9.208e-02
# Iter 100, loss = 2.617e-04
# Iter 200, loss = 1.357e-04
# Iter 300, loss = 5.919e-05
# Iter 400, loss = 2.239e-05
# Iter 500, loss = 7.433e-06
# Iter 600, loss = 7.775e-06
# Iter 700, loss = 5.541e-07
# Iter 800, loss = 1.097e-05
# Iter 900, loss = 9.799e-05
# 202
# Iter 0, loss = 1.128e-01
# Iter 100, loss = 5.603e-06
# 203
# Iter 0, loss = 6.899e-02
# Iter 100, loss = 7.251e-07
# 204
# Iter 0, loss = 9.006e-02
# Iter 100, loss = 5.459e-04
# Iter 200, loss = 9.518e-06
# Iter 300, loss = 2.735e-07
# 205
# Iter 0, loss = 1.151e-01
# Iter 100, loss = 2.128e-04
# Iter 200, loss = 3.073e-05
# Iter 300, loss = 3.069e-06
# Iter 400, loss = 1.547e-05
# 206
# Iter 0, loss = 1.474e-01
# Iter 100, loss = 3.664e-03
# Iter 200, loss = 1.422e-04
# Iter 300, loss = 7.069e-07
# 207
# Iter 0, loss = 1.021e-01
# Iter 100, loss = 6.497e-04
# Iter 200, loss = 4.223e-04
# Iter 300, loss = 2.241e-04
# Iter 400, loss = 9.520e-05
# Iter 500, loss = 3.203e-05
# Iter 600, loss = 8.550e-06
# Iter 700, loss = 2.165e-06
# Iter 800, loss = 4.033e-06
# Iter 900, loss = 1.523e-04
# 208
# Iter 0, loss = 1.111e-01
# Iter 100, loss = 2.134e-05
# 209
# Iter 0, loss = 8.456e-02
# Iter 100, loss = 1.154e-04
# Iter 200, loss = 1.772e-08
# 210
# Iter 0, loss = 1.349e-01
# Iter 100, loss = 1.296e-05
# 211
# Iter 0, loss = 2.126e-01
# Iter 100, loss = 6.788e-04
# Iter 200, loss = 1.876e-04
# Iter 300, loss = 5.655e-05
# Iter 400, loss = 1.340e-05
# Iter 500, loss = 2.504e-06
# Iter 600, loss = 3.681e-07
# Iter 700, loss = 2.694e-06
# 212
# Iter 0, loss = 1.007e-01
# Iter 100, loss = 2.033e-04
# Iter 200, loss = 2.351e-06
# 213
# Iter 0, loss = 8.202e-02
# Iter 100, loss = 2.787e-05
# Iter 200, loss = 1.528e-05
# Iter 300, loss = 7.597e-06
# Iter 400, loss = 3.636e-06
# Iter 500, loss = 1.322e-06
# Iter 600, loss = 4.775e-07
# Iter 700, loss = 3.194e-07
# Iter 800, loss = 1.099e-07
# Iter 900, loss = 1.556e-05
# 214
# Iter 0, loss = 9.129e-02
# Iter 100, loss = 1.747e-06
# 215
# Iter 0, loss = 1.123e-01
# Iter 100, loss = 3.855e-05
# Iter 200, loss = 3.406e-07
# 216
# Iter 0, loss = 8.643e-02
# Iter 100, loss = 4.126e-05
# 217
# Iter 0, loss = 1.234e-01
# Iter 100, loss = 4.291e-05
# 218
# Iter 0, loss = 1.185e-01
# Iter 100, loss = 1.700e-06
# 219
# Iter 0, loss = 7.079e-02
# Iter 100, loss = 1.351e-05
# Iter 200, loss = 5.593e-08
# 220
# Iter 0, loss = 7.888e-02
# Iter 100, loss = 2.113e-05
# Iter 200, loss = 8.379e-07
# 221
# Iter 0, loss = 1.404e-01
# Iter 100, loss = 2.852e-04
# Iter 200, loss = 4.002e-06
# 222
# Iter 0, loss = 1.076e-01
# Iter 100, loss = 4.789e-04
# Iter 200, loss = 1.914e-05
# Iter 300, loss = 3.498e-07
# 223
# Iter 0, loss = 8.377e-02
# Iter 100, loss = 5.152e-06
# 224
# Iter 0, loss = 2.265e-01
# Iter 100, loss = 1.139e-03
# Iter 200, loss = 9.167e-04
# Iter 300, loss = 6.732e-04
# Iter 400, loss = 4.466e-04
# Iter 500, loss = 2.648e-04
# Iter 600, loss = 1.389e-04
# Iter 700, loss = 6.409e-05
# Iter 800, loss = 2.605e-05
# Iter 900, loss = 9.292e-06
# 225
# Iter 0, loss = 1.333e-01
# Iter 100, loss = 1.123e-05
# 226
# Iter 0, loss = 8.412e-02
# Iter 100, loss = 2.015e-06
# 227
# Iter 0, loss = 6.588e-02
# Iter 100, loss = 4.166e-06
# 228
# Iter 0, loss = 1.292e-01
# Iter 100, loss = 1.889e-04
# Iter 200, loss = 4.377e-05
# Iter 300, loss = 1.392e-05
# Iter 400, loss = 3.482e-06
# Iter 500, loss = 4.340e-05
# Iter 600, loss = 1.081e-07
# Iter 700, loss = 3.815e-07
# 229
# Iter 0, loss = 1.011e-01
# Iter 100, loss = 2.142e-04
# Iter 200, loss = 3.729e-05
# Iter 300, loss = 6.060e-06
# Iter 400, loss = 7.170e-07
# Iter 500, loss = 5.779e-08
# Iter 600, loss = 7.136e-07
# 230
# Iter 0, loss = 6.938e-02
# Iter 100, loss = 7.739e-07
# 231
# Iter 0, loss = 1.015e-01
# Iter 100, loss = 1.474e-06
# Iter 200, loss = 1.105e-07
# Iter 300, loss = 4.961e-07
# 232
# Iter 0, loss = 1.236e-01
# Iter 100, loss = 3.949e-05
# Iter 200, loss = 1.426e-06
# Iter 300, loss = 1.507e-06
# 233
# Iter 0, loss = 8.228e-02
# Iter 100, loss = 2.977e-05
# Iter 200, loss = 4.042e-06
# Iter 300, loss = 2.695e-07
# 234
# Iter 0, loss = 1.146e-01
# Iter 100, loss = 1.686e-03
# Iter 200, loss = 3.286e-05
# Iter 300, loss = 1.174e-06
# 235
# Iter 0, loss = 1.076e-01
# Iter 100, loss = 7.302e-04
# Iter 200, loss = 5.184e-04
# Iter 300, loss = 3.531e-04
# Iter 400, loss = 2.301e-04
# Iter 500, loss = 1.452e-04
# Iter 600, loss = 8.925e-05
# Iter 700, loss = 5.423e-05
# Iter 800, loss = 3.236e-05
# Iter 900, loss = 1.782e-05
# 236
# Iter 0, loss = 9.614e-02
# Iter 100, loss = 1.133e-06
# 237
# Iter 0, loss = 8.668e-02
# Iter 100, loss = 1.337e-06
# 238
# Iter 0, loss = 3.318e-01
# Iter 100, loss = 8.249e-04
# Iter 200, loss = 1.083e-04
# Iter 300, loss = 3.446e-05
# Iter 400, loss = 1.171e-05
# Iter 500, loss = 3.345e-06
# Iter 600, loss = 8.007e-07
# Iter 700, loss = 1.601e-07
# Iter 800, loss = 2.677e-08
# 239
# Iter 0, loss = 1.006e-01
# Iter 100, loss = 8.836e-05
# Iter 200, loss = 1.555e-06
# 240
# Iter 0, loss = 6.693e-02
# Iter 100, loss = 3.355e-06
# 241
# Iter 0, loss = 9.203e-02
# Iter 100, loss = 1.482e-06
# 242
# Iter 0, loss = 9.488e-02
# Iter 100, loss = 5.459e-04
# Iter 200, loss = 1.230e-04
# Iter 300, loss = 2.382e-05
# Iter 400, loss = 4.035e-06
# Iter 500, loss = 6.250e-07
# Iter 600, loss = 2.243e-06
# Iter 700, loss = 8.259e-07
# 243
# Iter 0, loss = 1.503e-01
# Iter 100, loss = 8.010e-04
# Iter 200, loss = 6.978e-05
# Iter 300, loss = 2.426e-06
# Iter 400, loss = 3.351e-08
# 244
# Iter 0, loss = 1.011e-01
# Iter 100, loss = 3.407e-03
# Iter 200, loss = 5.039e-04
# Iter 300, loss = 2.024e-05
# Iter 400, loss = 1.285e-06
# 245
# Iter 0, loss = 1.151e-01
# Iter 100, loss = 4.559e-06
# 246
# Iter 0, loss = 9.428e-02
# Iter 100, loss = 1.094e-04
# Iter 200, loss = 5.915e-08
# 247
# Iter 0, loss = 6.581e-02
# Iter 100, loss = 2.287e-06
# Iter 200, loss = 1.189e-06
# Iter 300, loss = 8.930e-07
# Iter 400, loss = 6.303e-07
# Iter 500, loss = 1.062e-05
# Iter 600, loss = 1.004e-05
# Iter 700, loss = 1.954e-06
# Iter 800, loss = 4.555e-07
# Iter 900, loss = 4.613e-05
# 248
# Iter 0, loss = 1.042e-01
# Iter 100, loss = 5.488e-03
# Iter 200, loss = 3.376e-03
# Iter 300, loss = 1.535e-03
# Iter 400, loss = 4.931e-04
# Iter 500, loss = 1.114e-04
# Iter 600, loss = 1.805e-05
# Iter 700, loss = 2.196e-06
# Iter 800, loss = 4.489e-07
# Iter 900, loss = 2.742e-06
# 249
# Iter 0, loss = 1.304e-01
# Iter 100, loss = 2.313e-05
# 250
# Iter 0, loss = 9.302e-02
# Iter 100, loss = 1.642e-04
# Iter 200, loss = 8.698e-06
# Iter 300, loss = 1.303e-07
# 251
# Iter 0, loss = 1.251e-01
# Iter 100, loss = 7.000e-03
# Iter 200, loss = 3.331e-03
# Iter 300, loss = 1.579e-03
# Iter 400, loss = 7.721e-04
# Iter 500, loss = 3.872e-04
# Iter 600, loss = 1.966e-04
# Iter 700, loss = 9.959e-05
# Iter 800, loss = 4.990e-05
# Iter 900, loss = 2.573e-05
# 252
# Iter 0, loss = 1.170e-01
# Iter 100, loss = 3.454e-05
# Iter 200, loss = 7.365e-07
# 253
# Iter 0, loss = 1.182e-01
# Iter 100, loss = 2.639e-03
# Iter 200, loss = 8.201e-04
# Iter 300, loss = 2.055e-04
# Iter 400, loss = 4.254e-05
# Iter 500, loss = 7.177e-06
# Iter 600, loss = 1.040e-06
# Iter 700, loss = 4.691e-07
# Iter 800, loss = 4.330e-06
# 254
# Iter 0, loss = 8.193e-02
# Iter 100, loss = 4.363e-06
# 255
# Iter 0, loss = 1.107e-01
# Iter 100, loss = 1.034e-03
# Iter 200, loss = 8.359e-04
# Iter 300, loss = 6.192e-04
# Iter 400, loss = 4.088e-04
# Iter 500, loss = 2.351e-04
# Iter 600, loss = 1.155e-04
# Iter 700, loss = 4.743e-05
# Iter 800, loss = 1.655e-05
# Iter 900, loss = 4.940e-06
# 256
# Iter 0, loss = 6.552e-02
# Iter 100, loss = 6.066e-05
# 257
# Iter 0, loss = 9.162e-02
# Iter 100, loss = 1.728e-04
# Iter 200, loss = 4.225e-05
# Iter 300, loss = 7.898e-06
# Iter 400, loss = 1.117e-06
# Iter 500, loss = 1.174e-07
# Iter 600, loss = 4.098e-08
# 258
# Iter 0, loss = 1.367e-01
# Iter 100, loss = 1.302e-04
# Iter 200, loss = 1.112e-05
# Iter 300, loss = 3.606e-07
# 259
# Iter 0, loss = 1.609e-01
# Iter 100, loss = 6.058e-05
# Iter 200, loss = 1.284e-06
# Iter 300, loss = 2.706e-07
# Iter 400, loss = 4.016e-08
# 260
# Iter 0, loss = 8.941e-02
# Iter 100, loss = 5.973e-05
# Iter 200, loss = 2.380e-05
# Iter 300, loss = 7.556e-06
# Iter 400, loss = 1.944e-06
# Iter 500, loss = 4.078e-07
# Iter 600, loss = 1.392e-07
# Iter 700, loss = 2.113e-08
# 261
# Iter 0, loss = 8.431e-02
# Iter 100, loss = 7.851e-06
# 262
# Iter 0, loss = 8.833e-02
# Iter 100, loss = 1.077e-06
# 263
# Iter 0, loss = 7.299e-02
# Iter 100, loss = 1.714e-04
# Iter 200, loss = 2.792e-07
# 264
# Iter 0, loss = 1.036e-01
# Iter 100, loss = 2.698e-06
# 265
# Iter 0, loss = 1.004e-01
# Iter 100, loss = 3.999e-06
# 266
# Iter 0, loss = 1.098e-01
# Iter 100, loss = 8.471e-05
# Iter 200, loss = 2.579e-05
# Iter 300, loss = 5.180e-06
# Iter 400, loss = 1.038e-06
# Iter 500, loss = 6.134e-08
# 267
# Iter 0, loss = 9.996e-02
# Iter 100, loss = 1.473e-05
# Iter 200, loss = 7.805e-08
# 268
# Iter 0, loss = 1.386e-01
# Iter 100, loss = 9.012e-03
# Iter 200, loss = 3.447e-03
# Iter 300, loss = 9.180e-04
# Iter 400, loss = 1.412e-04
# Iter 500, loss = 1.257e-05
# Iter 600, loss = 5.310e-07
# Iter 700, loss = 8.504e-08
# 269
# Iter 0, loss = 1.262e-01
# Iter 100, loss = 8.494e-04
# Iter 200, loss = 1.948e-04
# Iter 300, loss = 3.110e-05
# Iter 400, loss = 3.505e-06
# Iter 500, loss = 5.498e-07
# Iter 600, loss = 1.534e-08
# 270
# Iter 0, loss = 1.575e-01
# Iter 100, loss = 5.872e-03
# Iter 200, loss = 2.444e-03
# Iter 300, loss = 1.140e-03
# Iter 400, loss = 5.510e-04
# Iter 500, loss = 2.803e-04
# Iter 600, loss = 1.498e-04
# Iter 700, loss = 8.512e-05
# Iter 800, loss = 1.076e-04
# Iter 900, loss = 2.889e-05
# 271
# Iter 0, loss = 1.645e-01
# Iter 100, loss = 6.010e-04
# Iter 200, loss = 8.184e-05
# Iter 300, loss = 5.294e-06
# Iter 400, loss = 2.116e-07
# 272
# Iter 0, loss = 1.359e-01
# Iter 100, loss = 8.560e-06
# Iter 200, loss = 2.994e-07
# 273
# Iter 0, loss = 7.272e-02
# Iter 100, loss = 3.143e-06
# 274
# Iter 0, loss = 3.987e-01
# Iter 100, loss = 1.877e-03
# Iter 200, loss = 4.828e-04
# Iter 300, loss = 1.016e-04
# Iter 400, loss = 1.872e-05
# Iter 500, loss = 2.995e-06
# Iter 600, loss = 3.968e-07
# Iter 700, loss = 4.169e-08
# 275
# Iter 0, loss = 1.934e-01
# Iter 100, loss = 5.754e-05
# Iter 200, loss = 2.098e-06
# Iter 300, loss = 2.781e-07
# Iter 400, loss = 3.934e-08
# Iter 500, loss = 3.002e-08
# 276
# Iter 0, loss = 1.037e-01
# Iter 100, loss = 8.515e-06
# 277
# Iter 0, loss = 1.593e-01
# Iter 100, loss = 4.798e-05
# Iter 200, loss = 1.513e-06
# Iter 300, loss = 2.204e-08
# 278
# Iter 0, loss = 9.661e-02
# Iter 100, loss = 1.413e-04
# Iter 200, loss = 4.068e-08
# 279
# Iter 0, loss = 7.837e-02
# Iter 100, loss = 1.113e-03
# Iter 200, loss = 4.327e-04
# Iter 300, loss = 1.392e-04
# Iter 400, loss = 4.131e-05
# Iter 500, loss = 9.639e-06
# Iter 600, loss = 2.848e-06
# Iter 700, loss = 4.550e-07
# Iter 800, loss = 9.915e-08
# Iter 900, loss = 6.070e-07
# 280
# Iter 0, loss = 2.468e-01
# Iter 100, loss = 3.127e-03
# Iter 200, loss = 9.192e-04
# Iter 300, loss = 2.127e-04
# Iter 400, loss = 3.909e-05
# Iter 500, loss = 5.513e-06
# Iter 600, loss = 7.235e-07
# Iter 700, loss = 1.146e-05
# 281
# Iter 0, loss = 8.022e-02
# Iter 100, loss = 1.190e-06
# Iter 200, loss = 9.288e-08
# Iter 300, loss = 1.211e-08
# 282
# Iter 0, loss = 2.707e-01
# Iter 100, loss = 9.585e-03
# Iter 200, loss = 3.108e-03
# Iter 300, loss = 5.583e-04
# Iter 400, loss = 5.054e-05
# Iter 500, loss = 5.236e-06
# Iter 600, loss = 1.866e-05
# 283
# Iter 0, loss = 1.160e-01
# Iter 100, loss = 3.067e-04
# Iter 200, loss = 1.304e-05
# Iter 300, loss = 2.295e-07
# 284
# Iter 0, loss = 1.308e-01
# Iter 100, loss = 6.883e-03
# Iter 200, loss = 2.779e-04
# Iter 300, loss = 4.523e-07
# 285
# Iter 0, loss = 1.355e-01
# Iter 100, loss = 5.621e-04
# Iter 200, loss = 1.260e-05
# Iter 300, loss = 5.235e-08
# 286
# Iter 0, loss = 8.388e-02
# Iter 100, loss = 2.203e-05
# 287
# Iter 0, loss = 1.333e-01
# Iter 100, loss = 1.871e-04
# Iter 200, loss = 4.862e-06
# Iter 300, loss = 4.847e-08
# 288
# Iter 0, loss = 2.425e-01
# Iter 100, loss = 1.927e-02
# Iter 200, loss = 7.549e-03
# Iter 300, loss = 3.241e-03
# Iter 400, loss = 1.699e-03
# Iter 500, loss = 1.070e-03
# Iter 600, loss = 7.760e-04
# Iter 700, loss = 7.621e-04
# Iter 800, loss = 5.342e-04
# Iter 900, loss = 4.840e-04
# 289
# Iter 0, loss = 1.537e-01
# Iter 100, loss = 2.481e-03
# Iter 200, loss = 1.775e-03
# Iter 300, loss = 1.207e-03
# Iter 400, loss = 7.859e-04
# Iter 500, loss = 5.016e-04
# Iter 600, loss = 3.118e-04
# Iter 700, loss = 1.902e-04
# Iter 800, loss = 1.149e-04
# Iter 900, loss = 6.901e-05
# 290
# Iter 0, loss = 1.081e-01
# Iter 100, loss = 2.488e-05
# Iter 200, loss = 3.089e-08
# 291
# Iter 0, loss = 8.686e-02
# Iter 100, loss = 1.861e-06
# 292
# Iter 0, loss = 9.160e-02
# Iter 100, loss = 2.293e-04
# Iter 200, loss = 3.864e-05
# Iter 300, loss = 4.364e-06
# Iter 400, loss = 3.285e-07
# Iter 500, loss = 1.575e-08
# 293
# Iter 0, loss = 1.408e-01
# Iter 100, loss = 7.873e-05
# Iter 200, loss = 4.255e-05
# Iter 300, loss = 3.096e-05
# Iter 400, loss = 2.111e-05
# Iter 500, loss = 1.354e-05
# Iter 600, loss = 8.203e-06
# Iter 700, loss = 4.693e-06
# Iter 800, loss = 2.543e-06
# Iter 900, loss = 1.355e-06
# 294
# Iter 0, loss = 9.164e-02
# Iter 100, loss = 1.626e-04
# Iter 200, loss = 9.027e-07
# 295
# Iter 0, loss = 1.470e-01
# Iter 100, loss = 4.236e-05
# Iter 200, loss = 1.752e-05
# Iter 300, loss = 7.653e-06
# Iter 400, loss = 2.807e-06
# Iter 500, loss = 9.063e-07
# Iter 600, loss = 1.856e-06
# Iter 700, loss = 1.019e-05
# Iter 800, loss = 1.366e-05
# 296
# Iter 0, loss = 8.074e-02
# Iter 100, loss = 1.237e-06
# 297
# Iter 0, loss = 1.204e-01
# Iter 100, loss = 1.137e-04
# Iter 200, loss = 6.477e-05
# Iter 300, loss = 3.004e-05
# Iter 400, loss = 1.181e-05
# Iter 500, loss = 2.051e-05
# Iter 600, loss = 8.627e-07
# Iter 700, loss = 2.058e-07
# Iter 800, loss = 1.830e-07
# Iter 900, loss = 6.089e-06
# 298
# Iter 0, loss = 2.281e-01
# Iter 100, loss = 1.109e-03
# Iter 200, loss = 1.059e-04
# Iter 300, loss = 5.701e-06
# Iter 400, loss = 1.748e-07
# 299
# Iter 0, loss = 1.111e-01
# Iter 100, loss = 5.835e-03
# Iter 200, loss = 4.156e-03
# Iter 300, loss = 2.634e-03
# Iter 400, loss = 1.466e-03
# Iter 500, loss = 6.983e-04
# Iter 600, loss = 2.773e-04
# Iter 700, loss = 9.043e-05
# Iter 800, loss = 2.595e-05
# Iter 900, loss = 8.589e-06
# 300
# Iter 0, loss = 1.183e-01
# Iter 100, loss = 1.448e-04
# Iter 200, loss = 4.555e-07
# 301
# Iter 0, loss = 9.526e-02
# Iter 100, loss = 9.767e-05
# Iter 200, loss = 5.712e-07
# 302
# Iter 0, loss = 1.718e-01
# Iter 100, loss = 5.110e-04
# Iter 200, loss = 4.428e-05
# Iter 300, loss = 1.575e-06
# Iter 400, loss = 2.258e-08
# 303
# Iter 0, loss = 1.087e-01
# Iter 100, loss = 9.909e-05
# Iter 200, loss = 1.133e-06
# 304
# Iter 0, loss = 1.447e-01
# Iter 100, loss = 2.193e-04
# Iter 200, loss = 8.526e-05
# Iter 300, loss = 2.797e-05
# Iter 400, loss = 7.192e-06
# Iter 500, loss = 1.462e-06
# Iter 600, loss = 2.352e-07
# Iter 700, loss = 2.978e-08
# Iter 800, loss = 3.576e-09
# 305
# Iter 0, loss = 1.038e-01
# Iter 100, loss = 3.332e-05
# 306
# Iter 0, loss = 8.158e-02
# Iter 100, loss = 2.130e-06
# 307
# Iter 0, loss = 6.849e-02
# Iter 100, loss = 3.367e-06
# 308
# Iter 0, loss = 8.685e-02
# Iter 100, loss = 1.072e-05
# Iter 200, loss = 5.562e-07
# Iter 300, loss = 1.612e-05
# 309
# Iter 0, loss = 8.949e-02
# Iter 100, loss = 2.656e-04
# Iter 200, loss = 1.386e-06
# 310
# Iter 0, loss = 1.711e-01
# Iter 100, loss = 8.364e-04
# Iter 200, loss = 3.306e-04
# Iter 300, loss = 1.015e-04
# Iter 400, loss = 2.411e-05
# Iter 500, loss = 4.377e-06
# Iter 600, loss = 6.051e-07
# Iter 700, loss = 1.669e-07
# 311
# Iter 0, loss = 1.456e-01
# Iter 100, loss = 3.497e-03
# Iter 200, loss = 1.735e-03
# Iter 300, loss = 5.879e-04
# Iter 400, loss = 1.363e-04
# Iter 500, loss = 2.206e-05
# Iter 600, loss = 6.610e-06
# Iter 700, loss = 1.604e-06
# Iter 800, loss = 1.307e-06
# 312
# Iter 0, loss = 1.335e-01
# Iter 100, loss = 5.621e-04
# Iter 200, loss = 3.571e-06
# 313
# Iter 0, loss = 9.178e-02
# Iter 100, loss = 7.003e-04
# Iter 200, loss = 1.577e-04
# Iter 300, loss = 3.039e-05
# Iter 400, loss = 5.010e-06
# Iter 500, loss = 7.242e-06
# Iter 600, loss = 8.991e-08
# Iter 700, loss = 8.426e-08
# Iter 800, loss = 7.177e-05
# 314
# Iter 0, loss = 8.846e-02
# Iter 100, loss = 9.727e-07
# 315
# Iter 0, loss = 1.150e-01
# Iter 100, loss = 1.243e-06
# 316
# Iter 0, loss = 8.012e-02
# Iter 100, loss = 1.796e-05
# 317
# Iter 0, loss = 1.069e-01
# Iter 100, loss = 1.183e-06
# 318
# Iter 0, loss = 1.028e-01
# Iter 100, loss = 3.226e-04
# Iter 200, loss = 1.438e-05
# Iter 300, loss = 2.721e-07
# 319
# Iter 0, loss = 7.734e-02
# Iter 100, loss = 1.533e-05
# 320
# Iter 0, loss = 9.603e-02
# Iter 100, loss = 3.710e-03
# Iter 200, loss = 1.924e-03
# Iter 300, loss = 6.232e-04
# Iter 400, loss = 1.168e-04
# Iter 500, loss = 2.086e-05
# Iter 600, loss = 3.512e-06
# Iter 700, loss = 3.752e-05
# Iter 800, loss = 1.448e-06
# Iter 900, loss = 2.861e-05
# 321
# Iter 0, loss = 1.159e-01
# Iter 100, loss = 1.034e-03
# Iter 200, loss = 1.463e-04
# Iter 300, loss = 1.194e-05
# Iter 400, loss = 1.641e-05
# Iter 500, loss = 1.498e-08
# 322
# Iter 0, loss = 1.403e-01
# Iter 100, loss = 3.866e-04
# Iter 200, loss = 2.823e-05
# Iter 300, loss = 2.136e-06
# Iter 400, loss = 9.638e-08
# Iter 500, loss = 1.076e-06
# 323
# Iter 0, loss = 1.096e-01
# Iter 100, loss = 1.464e-04
# Iter 200, loss = 1.200e-04
# Iter 300, loss = 9.286e-05
# Iter 400, loss = 6.733e-05
# Iter 500, loss = 1.088e-04
# Iter 600, loss = 2.873e-05
# Iter 700, loss = 1.720e-05
# Iter 800, loss = 1.101e-04
# Iter 900, loss = 4.895e-06
# 324
# Iter 0, loss = 9.539e-02
# Iter 100, loss = 1.093e-06
# 325
# Iter 0, loss = 1.027e-01
# Iter 100, loss = 6.476e-04
# Iter 200, loss = 2.561e-06
# 326
# Iter 0, loss = 1.093e-01
# Iter 100, loss = 8.721e-05
# Iter 200, loss = 6.731e-05
# Iter 300, loss = 4.910e-05
# Iter 400, loss = 3.392e-05
# Iter 500, loss = 2.270e-05
# Iter 600, loss = 2.588e-05
# Iter 700, loss = 8.788e-06
# Iter 800, loss = 5.129e-06
# Iter 900, loss = 3.929e-06
# 327
# Iter 0, loss = 7.395e-02
# Iter 100, loss = 2.966e-06
# 328
# Iter 0, loss = 1.034e-01
# Iter 100, loss = 1.004e-04
# Iter 200, loss = 1.422e-05
# Iter 300, loss = 1.012e-06
# Iter 400, loss = 3.664e-08
# 329
# Iter 0, loss = 1.728e-01
# Iter 100, loss = 8.257e-04
# Iter 200, loss = 8.580e-05
# Iter 300, loss = 8.952e-06
# Iter 400, loss = 1.649e-05
# 330
# Iter 0, loss = 1.160e-01
# Iter 100, loss = 3.790e-05
# Iter 200, loss = 1.698e-08
# 331
# Iter 0, loss = 1.487e-01
# Iter 100, loss = 4.245e-04
# Iter 200, loss = 4.759e-05
# Iter 300, loss = 1.377e-05
# Iter 400, loss = 4.034e-06
# Iter 500, loss = 1.279e-06
# Iter 600, loss = 4.161e-06
# Iter 700, loss = 3.122e-07
# Iter 800, loss = 1.541e-06
# Iter 900, loss = 1.049e-05
# 332
# Iter 0, loss = 1.261e-01
# Iter 100, loss = 7.063e-05
# Iter 200, loss = 2.474e-05
# Iter 300, loss = 9.198e-06
# Iter 400, loss = 2.794e-06
# Iter 500, loss = 2.869e-06
# Iter 600, loss = 1.486e-07
# Iter 700, loss = 1.123e-06
# 333
# Iter 0, loss = 1.239e-01
# Iter 100, loss = 2.024e-03
# Iter 200, loss = 2.975e-04
# Iter 300, loss = 2.935e-05
# Iter 400, loss = 2.156e-06
# Iter 500, loss = 1.605e-07
# 334
# Iter 0, loss = 1.526e-01
# Iter 100, loss = 5.755e-04
# Iter 200, loss = 1.039e-04
# Iter 300, loss = 9.169e-06
# Iter 400, loss = 4.141e-07
# Iter 500, loss = 3.839e-08
# 335
# Iter 0, loss = 1.127e-01
# Iter 100, loss = 1.287e-03
# Iter 200, loss = 1.115e-03
# Iter 300, loss = 9.310e-04
# Iter 400, loss = 7.551e-04
# Iter 500, loss = 5.961e-04
# Iter 600, loss = 4.570e-04
# Iter 700, loss = 3.404e-04
# Iter 800, loss = 2.415e-04
# Iter 900, loss = 1.641e-04
# 336
# Iter 0, loss = 9.324e-02
# Iter 100, loss = 2.979e-03
# Iter 200, loss = 1.877e-03
# Iter 300, loss = 1.175e-03
# Iter 400, loss = 7.336e-04
# Iter 500, loss = 4.510e-04
# Iter 600, loss = 2.738e-04
# Iter 700, loss = 1.558e-04
# Iter 800, loss = 9.602e-05
# Iter 900, loss = 4.899e-05
# 337
# Iter 0, loss = 1.072e-01
# Iter 100, loss = 5.130e-05
# Iter 200, loss = 1.055e-08
# 338
# Iter 0, loss = 1.326e-01
# Iter 100, loss = 1.391e-03
# Iter 200, loss = 1.356e-03
# Iter 300, loss = 1.335e-03
# Iter 400, loss = 1.319e-03
# Iter 500, loss = 1.308e-03
# Iter 600, loss = 1.306e-03
# Iter 700, loss = 1.301e-03
# Iter 800, loss = 1.361e-03
# Iter 900, loss = 1.296e-03
# 339
# Iter 0, loss = 9.738e-02
# Iter 100, loss = 4.238e-04
# Iter 200, loss = 2.182e-05
# Iter 300, loss = 4.498e-07
# 340
# Iter 0, loss = 1.098e-01
# Iter 100, loss = 1.074e-04
# Iter 200, loss = 8.731e-05
# Iter 300, loss = 6.909e-05
# Iter 400, loss = 5.228e-05
# Iter 500, loss = 3.803e-05
# Iter 600, loss = 2.666e-05
# Iter 700, loss = 1.805e-05
# Iter 800, loss = 1.188e-05
# Iter 900, loss = 2.334e-05
# 341
# Iter 0, loss = 1.380e-01
# Iter 100, loss = 4.638e-03
# Iter 200, loss = 1.474e-03
# Iter 300, loss = 2.316e-04
# Iter 400, loss = 1.750e-05
# Iter 500, loss = 6.799e-07
# Iter 600, loss = 1.677e-06
# 342
# Iter 0, loss = 1.201e-01
# Iter 100, loss = 2.599e-04
# Iter 200, loss = 1.130e-04
# Iter 300, loss = 5.235e-05
# Iter 400, loss = 2.184e-05
# ...
# 874
# Iter 0, loss = 1.058e-01
# Iter 100, loss = 3.506e-04
# Iter 200, loss = 1.375e-04
# Iter 300, loss = 5.813e-05
# Iter 400, loss = 2.318e-05
# Iter 500, loss = 8.747e-06
# Iter 600, loss = 3.263e-06
# Iter 700, loss = 1.065e-06
# Iter 800, loss = 1.639e-05
# Iter 900, loss = 6.691e-07
# 875
# Iter 0, loss = 1.082e-01
# Iter 100, loss = 9.697e-05
# 876
# Iter 0, loss = 1.035e-01
# Iter 100, loss = 1.820e-04
# Iter 200, loss = 2.682e-06
# 877
# Iter 0, loss = 9.476e-02
# Iter 100, loss = 2.472e-05
# Iter 200, loss = 1.878e-08
# 878
# Iter 0, loss = 9.920e-02
# Iter 100, loss = 5.168e-04
# Iter 200, loss = 1.187e-04
# Iter 300, loss = 2.374e-05
# Iter 400, loss = 3.974e-06
# Iter 500, loss = 6.767e-07
# Iter 600, loss = 1.138e-05
# Iter 700, loss = 1.318e-06
# 879
# Iter 0, loss = 1.427e-01
# Iter 100, loss = 1.397e-03
# Iter 200, loss = 1.652e-04
# Iter 300, loss = 7.496e-06
# Iter 400, loss = 1.303e-07
# 880
# Iter 0, loss = 1.222e-01
# Iter 100, loss = 3.980e-04
# Iter 200, loss = 3.200e-05
# Iter 300, loss = 1.400e-06
# Iter 400, loss = 3.140e-07
# 881
# Iter 0, loss = 9.988e-02
# Iter 100, loss = 1.407e-06
# 882
# Iter 0, loss = 1.245e-01
# Iter 100, loss = 4.385e-04
# Iter 200, loss = 2.051e-05
# Iter 300, loss = 4.401e-07
# 883
# Iter 0, loss = 7.964e-02
# Iter 100, loss = 2.319e-05
# 884
# Iter 0, loss = 8.323e-02
# Iter 100, loss = 6.808e-06
# 885
# Iter 0, loss = 8.234e-02
# Iter 100, loss = 2.249e-05
# 886
# Iter 0, loss = 9.583e-02
# Iter 100, loss = 1.219e-04
# Iter 200, loss = 1.134e-05
# Iter 300, loss = 3.965e-07
# 887
# Iter 0, loss = 9.766e-02
# Iter 100, loss = 9.017e-06
# 888
# Iter 0, loss = 8.591e-02
# Iter 100, loss = 5.096e-05
# 889
# Iter 0, loss = 9.467e-02
# Iter 100, loss = 3.122e-03
# Iter 200, loss = 1.065e-03
# Iter 300, loss = 1.883e-04
# Iter 400, loss = 1.646e-05
# Iter 500, loss = 3.003e-06
# Iter 600, loss = 4.281e-07
# Iter 700, loss = 3.230e-08
# 890
# Iter 0, loss = 1.276e-01
# Iter 100, loss = 9.387e-05
# Iter 200, loss = 8.909e-07
# 891
# Iter 0, loss = 1.630e-01
# Iter 100, loss = 5.189e-04
# Iter 200, loss = 8.732e-05
# Iter 300, loss = 6.745e-06
# Iter 400, loss = 3.150e-07
# Iter 500, loss = 1.390e-08
# 892
# Iter 0, loss = 1.467e-01
# Iter 100, loss = 2.516e-03
# Iter 200, loss = 8.955e-05
# Iter 300, loss = 3.060e-07
# 893
# Iter 0, loss = 1.210e-01
# Iter 100, loss = 1.566e-04
# Iter 200, loss = 4.103e-05
# Iter 300, loss = 8.537e-06
# Iter 400, loss = 1.319e-06
# Iter 500, loss = 1.457e-07
# Iter 600, loss = 7.526e-08
# 894
# Iter 0, loss = 8.164e-02
# Iter 100, loss = 1.800e-06
# 895
# Iter 0, loss = 1.249e-01
# Iter 100, loss = 1.081e-03
# Iter 200, loss = 4.251e-04
# Iter 300, loss = 1.211e-04
# Iter 400, loss = 2.292e-05
# Iter 500, loss = 3.515e-06
# Iter 600, loss = 3.080e-07
# Iter 700, loss = 3.374e-08
# Iter 800, loss = 2.402e-07
# 896
# Iter 0, loss = 8.535e-02
# Iter 100, loss = 1.304e-06
# 897
# Iter 0, loss = 8.318e-02
# Iter 100, loss = 1.164e-06
# 898
# Iter 0, loss = 1.084e-01
# Iter 100, loss = 2.945e-05
# Iter 200, loss = 9.394e-08
# 899
# Iter 0, loss = 1.749e-01
# Iter 100, loss = 1.481e-04
# Iter 200, loss = 1.259e-05
# Iter 300, loss = 7.029e-07
# Iter 400, loss = 1.870e-08
# 900
# Iter 0, loss = 8.873e-02
# Iter 100, loss = 2.203e-04
# Iter 200, loss = 3.050e-05
# Iter 300, loss = 2.551e-06
# Iter 400, loss = 2.367e-06
# Iter 500, loss = 4.041e-06
# 901
# Iter 0, loss = 1.309e-01
# Iter 100, loss = 1.150e-03
# Iter 200, loss = 5.099e-05
# Iter 300, loss = 6.014e-07
# Iter 400, loss = 1.299e-06
# 902
# Iter 0, loss = 1.487e-01
# Iter 100, loss = 4.095e-04
# Iter 200, loss = 1.549e-04
# Iter 300, loss = 5.476e-05
# Iter 400, loss = 1.616e-05
# Iter 500, loss = 1.005e-05
# Iter 600, loss = 8.075e-07
# Iter 700, loss = 2.096e-07
# Iter 800, loss = 2.049e-07
# Iter 900, loss = 2.580e-07
# 903
# Iter 0, loss = 1.441e-01
# Iter 100, loss = 1.219e-03
# Iter 200, loss = 6.346e-05
# Iter 300, loss = 7.579e-07
# 904
# Iter 0, loss = 8.083e-02
# Iter 100, loss = 5.582e-05
# Iter 200, loss = 1.925e-07
# 905
# Iter 0, loss = 1.009e-01
# Iter 100, loss = 1.912e-05
# 906
# Iter 0, loss = 7.968e-02
# Iter 100, loss = 3.004e-03
# Iter 200, loss = 2.199e-03
# Iter 300, loss = 1.590e-03
# Iter 400, loss = 1.136e-03
# Iter 500, loss = 7.880e-04
# Iter 600, loss = 5.173e-04
# Iter 700, loss = 3.147e-04
# Iter 800, loss = 1.850e-04
# Iter 900, loss = 8.635e-05
# 907
# Iter 0, loss = 8.697e-02
# Iter 100, loss = 1.698e-04
# Iter 200, loss = 1.184e-04
# Iter 300, loss = 7.585e-05
# Iter 400, loss = 4.547e-05
# Iter 500, loss = 2.578e-05
# Iter 600, loss = 1.502e-05
# Iter 700, loss = 4.058e-05
# Iter 800, loss = 3.578e-06
# Iter 900, loss = 1.846e-06
# 908
# Iter 0, loss = 2.020e-01
# Iter 100, loss = 1.015e-03
# Iter 200, loss = 2.567e-05
# Iter 300, loss = 1.340e-07
# 909
# Iter 0, loss = 7.924e-02
# Iter 100, loss = 7.365e-05
# Iter 200, loss = 6.335e-06
# Iter 300, loss = 2.251e-07
# 910
# Iter 0, loss = 9.281e-02
# Iter 100, loss = 6.395e-04
# Iter 200, loss = 5.213e-04
# Iter 300, loss = 3.896e-04
# Iter 400, loss = 2.637e-04
# Iter 500, loss = 1.594e-04
# Iter 600, loss = 8.475e-05
# Iter 700, loss = 3.927e-05
# Iter 800, loss = 1.579e-05
# Iter 900, loss = 5.600e-06
# 911
# Iter 0, loss = 1.282e-01
# Iter 100, loss = 1.839e-04
# Iter 200, loss = 4.352e-06
# Iter 300, loss = 1.136e-08
# 912
# Iter 0, loss = 1.366e-01
# Iter 100, loss = 1.173e-03
# Iter 200, loss = 1.092e-05
# 913
# Iter 0, loss = 9.969e-02
# Iter 100, loss = 2.150e-06
# 914
# Iter 0, loss = 8.248e-02
# Iter 100, loss = 1.750e-03
# Iter 200, loss = 1.145e-03
# Iter 300, loss = 7.015e-04
# Iter 400, loss = 4.167e-04
# Iter 500, loss = 2.433e-04
# Iter 600, loss = 1.399e-04
# Iter 700, loss = 7.921e-05
# Iter 800, loss = 4.401e-05
# Iter 900, loss = 2.394e-05
# 915
# Iter 0, loss = 7.387e-02
# Iter 100, loss = 2.308e-06
# Iter 200, loss = 1.465e-08
# 916
# Iter 0, loss = 1.115e-01
# Iter 100, loss = 2.296e-04
# Iter 200, loss = 1.743e-05
# Iter 300, loss = 7.317e-07
# Iter 400, loss = 1.526e-08
# 917
# Iter 0, loss = 1.214e-01
# Iter 100, loss = 2.181e-06
# 918
# Iter 0, loss = 7.153e-02
# Iter 100, loss = 2.162e-06
# 919
# Iter 0, loss = 1.108e-01
# Iter 100, loss = 3.022e-05
# 920
# Iter 0, loss = 1.314e-01
# Iter 100, loss = 5.004e-05
# Iter 200, loss = 9.735e-06
# Iter 300, loss = 1.194e-06
# Iter 400, loss = 8.881e-08
# 921
# Iter 0, loss = 3.293e-01
# Iter 100, loss = 7.498e-04
# Iter 200, loss = 1.266e-04
# Iter 300, loss = 5.539e-05
# Iter 400, loss = 3.325e-05
# Iter 500, loss = 1.916e-05
# Iter 600, loss = 1.072e-05
# Iter 700, loss = 1.771e-05
# Iter 800, loss = 2.556e-06
# Iter 900, loss = 1.183e-06
# 922
# Iter 0, loss = 8.784e-02
# Iter 100, loss = 1.512e-05
# Iter 200, loss = 1.068e-08
# 923
# Iter 0, loss = 1.226e-01
# Iter 100, loss = 7.599e-05
# Iter 200, loss = 4.173e-08
# 924
# Iter 0, loss = 1.034e-01
# Iter 100, loss = 2.554e-05
# Iter 200, loss = 2.990e-06
# Iter 300, loss = 9.104e-07
# Iter 400, loss = 2.121e-07
# Iter 500, loss = 3.828e-08
# 925
# Iter 0, loss = 7.667e-02
# Iter 100, loss = 5.489e-06
# 926
# Iter 0, loss = 1.029e-01
# Iter 100, loss = 5.334e-03
# Iter 200, loss = 8.476e-04
# Iter 300, loss = 3.694e-05
# Iter 400, loss = 4.609e-07
# 927
# Iter 0, loss = 8.530e-02
# Iter 100, loss = 2.806e-05
# Iter 200, loss = 2.290e-07
# 928
# Iter 0, loss = 1.047e-01
# Iter 100, loss = 2.300e-05
# Iter 200, loss = 3.557e-08
# 929
# Iter 0, loss = 1.377e-01
# Iter 100, loss = 6.182e-04
# Iter 200, loss = 8.190e-05
# Iter 300, loss = 5.977e-06
# Iter 400, loss = 2.342e-07
# 930
# Iter 0, loss = 1.090e-01
# Iter 100, loss = 3.908e-05
# Iter 200, loss = 2.151e-07
# 931
# Iter 0, loss = 7.242e-02
# Iter 100, loss = 7.093e-07
# 932
# Iter 0, loss = 1.124e-01
# Iter 100, loss = 1.255e-05
# Iter 200, loss = 3.227e-06
# Iter 300, loss = 1.899e-06
# Iter 400, loss = 5.649e-06
# Iter 500, loss = 4.633e-07
# Iter 600, loss = 6.584e-06
# Iter 700, loss = 9.426e-08
# Iter 800, loss = 6.083e-08
# Iter 900, loss = 1.033e-06
# 933
# Iter 0, loss = 2.388e-01
# Iter 100, loss = 7.055e-03
# Iter 200, loss = 3.125e-03
# Iter 300, loss = 8.311e-04
# Iter 400, loss = 1.279e-04
# Iter 500, loss = 1.181e-05
# Iter 600, loss = 7.047e-07
# Iter 700, loss = 3.545e-05
# 934
# Iter 0, loss = 8.080e-02
# Iter 100, loss = 9.998e-07
# 935
# Iter 0, loss = 7.562e-02
# Iter 100, loss = 2.214e-06
# 936
# Iter 0, loss = 1.112e-01
# Iter 100, loss = 1.649e-05
# Iter 200, loss = 5.556e-08
# 937
# Iter 0, loss = 1.066e-01
# Iter 100, loss = 3.032e-04
# Iter 200, loss = 7.061e-07
# 938
# Iter 0, loss = 1.013e-01
# Iter 100, loss = 1.670e-04
# Iter 200, loss = 3.052e-05
# Iter 300, loss = 2.846e-06
# Iter 400, loss = 1.807e-07
# 939
# Iter 0, loss = 6.271e-02
# Iter 100, loss = 1.048e-03
# Iter 200, loss = 5.197e-04
# Iter 300, loss = 1.759e-04
# Iter 400, loss = 4.689e-05
# Iter 500, loss = 6.190e-06
# Iter 600, loss = 6.748e-07
# Iter 700, loss = 2.745e-07
# Iter 800, loss = 9.189e-06
# 940
# Iter 0, loss = 9.396e-02
# Iter 100, loss = 4.542e-04
# Iter 200, loss = 1.769e-05
# Iter 300, loss = 1.166e-07
# 941
# Iter 0, loss = 1.503e-01
# Iter 100, loss = 1.376e-04
# Iter 200, loss = 1.036e-05
# Iter 300, loss = 4.225e-07
# 942
# Iter 0, loss = 1.077e-01
# Iter 100, loss = 1.044e-03
# Iter 200, loss = 4.284e-05
# Iter 300, loss = 9.690e-07
# 943
# Iter 0, loss = 1.185e-01
# Iter 100, loss = 6.340e-05
# Iter 200, loss = 1.500e-05
# Iter 300, loss = 2.065e-06
# Iter 400, loss = 8.544e-07
# Iter 500, loss = 5.910e-06
# 944
# Iter 0, loss = 9.050e-02
# Iter 100, loss = 3.726e-05
# Iter 200, loss = 7.683e-07
# 945
# Iter 0, loss = 1.250e-01
# Iter 100, loss = 1.069e-03
# Iter 200, loss = 5.352e-05
# Iter 300, loss = 1.334e-06
# Iter 400, loss = 1.346e-08
# 946
# Iter 0, loss = 1.025e-01
# Iter 100, loss = 8.561e-05
# Iter 200, loss = 8.194e-07
# 947
# Iter 0, loss = 1.534e-01
# Iter 100, loss = 5.120e-04
# Iter 200, loss = 9.115e-06
# Iter 300, loss = 4.389e-08
# 948
# Iter 0, loss = 7.628e-02
# Iter 100, loss = 9.665e-07
# 949
# Iter 0, loss = 1.034e-01
# Iter 100, loss = 5.216e-04
# Iter 200, loss = 2.480e-05
# Iter 300, loss = 2.203e-07
# 950
# Iter 0, loss = 1.297e-01
# Iter 100, loss = 1.309e-02
# Iter 200, loss = 1.082e-02
# Iter 300, loss = 7.503e-03
# Iter 400, loss = 3.672e-03
# Iter 500, loss = 1.021e-03
# Iter 600, loss = 1.495e-04
# Iter 700, loss = 1.265e-05
# Iter 800, loss = 7.091e-07
# Iter 900, loss = 2.676e-07
# 951
# Iter 0, loss = 1.148e-01
# Iter 100, loss = 2.962e-05
# 952
# Iter 0, loss = 1.123e-01
# Iter 100, loss = 3.795e-03
# Iter 200, loss = 1.293e-03
# Iter 300, loss = 4.156e-04
# Iter 400, loss = 1.283e-04
# Iter 500, loss = 3.719e-05
# Iter 600, loss = 9.885e-06
# Iter 700, loss = 2.498e-06
# Iter 800, loss = 5.858e-07
# Iter 900, loss = 1.497e-07
# 953
# Iter 0, loss = 1.031e-01
# Iter 100, loss = 1.202e-04
# 954
# Iter 0, loss = 8.974e-02
# Iter 100, loss = 2.633e-03
# Iter 200, loss = 2.039e-03
# Iter 300, loss = 1.530e-03
# Iter 400, loss = 1.131e-03
# Iter 500, loss = 8.239e-04
# Iter 600, loss = 5.873e-04
# Iter 700, loss = 4.052e-04
# Iter 800, loss = 2.800e-04
# Iter 900, loss = 1.738e-04
# 955
# Iter 0, loss = 9.495e-02
# Iter 100, loss = 1.170e-04
# Iter 200, loss = 5.098e-06
# Iter 300, loss = 5.789e-08
# 956
# Iter 0, loss = 1.014e-01
# Iter 100, loss = 3.691e-06
# 957
# Iter 0, loss = 8.670e-02
# Iter 100, loss = 1.416e-06
# 958
# Iter 0, loss = 1.818e-01
# Iter 100, loss = 1.153e-03
# Iter 200, loss = 4.541e-04
# Iter 300, loss = 1.550e-04
# Iter 400, loss = 4.128e-05
# Iter 500, loss = 1.035e-05
# Iter 600, loss = 1.265e-06
# Iter 700, loss = 1.605e-07
# Iter 800, loss = 8.743e-08
# 959
# Iter 0, loss = 1.021e-01
# Iter 100, loss = 2.636e-05
# 960
# Iter 0, loss = 1.532e-01
# Iter 100, loss = 4.353e-03
# Iter 200, loss = 1.015e-03
# Iter 300, loss = 9.367e-05
# Iter 400, loss = 3.445e-06
# Iter 500, loss = 5.532e-08
# 961
# Iter 0, loss = 1.482e-01
# Iter 100, loss = 1.555e-04
# Iter 200, loss = 8.416e-06
# Iter 300, loss = 2.015e-07
# Iter 400, loss = 6.637e-08
# 962
# Iter 0, loss = 1.442e-01
# Iter 100, loss = 5.414e-03
# Iter 200, loss = 8.129e-04
# Iter 300, loss = 8.947e-05
# Iter 400, loss = 6.818e-06
# Iter 500, loss = 5.457e-07
# Iter 600, loss = 1.834e-06
# 963
# Iter 0, loss = 8.067e-02
# Iter 100, loss = 1.994e-05
# 964
# Iter 0, loss = 1.132e-01
# Iter 100, loss = 2.521e-03
# Iter 200, loss = 4.828e-04
# Iter 300, loss = 6.950e-05
# Iter 400, loss = 8.254e-06
# Iter 500, loss = 5.712e-07
# Iter 600, loss = 4.665e-08
# Iter 700, loss = 7.813e-07
# Iter 800, loss = 6.358e-08
# 965
# Iter 0, loss = 7.046e-02
# Iter 100, loss = 6.926e-07
# 966
# Iter 0, loss = 8.371e-02
# Iter 100, loss = 1.337e-05
# Iter 200, loss = 9.629e-09
# 967
# Iter 0, loss = 1.030e-01
# Iter 100, loss = 5.890e-04
# Iter 200, loss = 8.139e-05
# Iter 300, loss = 8.327e-06
# Iter 400, loss = 5.913e-07
# Iter 500, loss = 2.703e-08
# 968
# Iter 0, loss = 9.713e-02
# Iter 100, loss = 5.822e-06
# 969
# Iter 0, loss = 1.582e-01
# Iter 100, loss = 5.200e-04
# Iter 200, loss = 9.323e-05
# Iter 300, loss = 1.810e-05
# Iter 400, loss = 2.464e-06
# Iter 500, loss = 2.258e-07
# Iter 600, loss = 5.485e-08
# 970
# Iter 0, loss = 1.478e-01
# Iter 100, loss = 1.052e-02
# Iter 200, loss = 4.737e-03
# Iter 300, loss = 1.891e-03
# Iter 400, loss = 7.458e-04
# Iter 500, loss = 3.069e-04
# Iter 600, loss = 1.327e-04
# Iter 700, loss = 6.011e-05
# Iter 800, loss = 3.774e-05
# Iter 900, loss = 1.368e-05
# 971
# Iter 0, loss = 1.012e-01
# Iter 100, loss = 4.725e-03
# Iter 200, loss = 2.147e-03
# Iter 300, loss = 1.294e-03
# Iter 400, loss = 9.334e-04
# Iter 500, loss = 7.579e-04
# Iter 600, loss = 6.666e-04
# Iter 700, loss = 6.119e-04
# Iter 800, loss = 5.832e-04
# Iter 900, loss = 5.707e-04
# 972
# Iter 0, loss = 9.072e-02
# Iter 100, loss = 8.059e-07
# 973
# Iter 0, loss = 2.223e-01
# Iter 100, loss = 3.030e-03
# Iter 200, loss = 2.756e-04
# Iter 300, loss = 1.332e-05
# Iter 400, loss = 2.985e-07
# 974
# Iter 0, loss = 1.503e-01
# Iter 100, loss = 6.693e-04
# Iter 200, loss = 2.439e-04
# Iter 300, loss = 7.131e-05
# Iter 400, loss = 1.677e-05
# Iter 500, loss = 3.224e-06
# Iter 600, loss = 1.450e-06
# Iter 700, loss = 3.471e-07
# Iter 800, loss = 6.274e-06
# 975
# Iter 0, loss = 1.094e-01
# Iter 100, loss = 2.517e-05
# Iter 200, loss = 2.881e-06
# Iter 300, loss = 1.558e-07
# Iter 400, loss = 6.666e-07
# 976
# Iter 0, loss = 1.007e-01
# Iter 100, loss = 6.933e-06
# 977
# Iter 0, loss = 1.396e-01
# Iter 100, loss = 3.399e-03
# Iter 200, loss = 9.543e-04
# Iter 300, loss = 1.304e-04
# Iter 400, loss = 8.284e-06
# Iter 500, loss = 2.760e-07
# Iter 600, loss = 5.972e-07
# 978
# Iter 0, loss = 9.167e-02
# Iter 100, loss = 1.165e-06
# 979
# Iter 0, loss = 9.692e-02
# Iter 100, loss = 2.827e-04
# Iter 200, loss = 9.155e-06
# Iter 300, loss = 6.252e-08
# 980
# Iter 0, loss = 7.040e-02
# Iter 100, loss = 2.036e-05
# 981
# Iter 0, loss = 9.578e-02
# Iter 100, loss = 1.154e-06
# 982
# Iter 0, loss = 8.319e-02
# Iter 100, loss = 1.327e-06
# 983
# Iter 0, loss = 8.675e-02
# Iter 100, loss = 6.848e-06
# 984
# Iter 0, loss = 1.353e-01
# Iter 100, loss = 1.974e-03
# Iter 200, loss = 1.036e-04
# Iter 300, loss = 1.258e-06
# 985
# Iter 0, loss = 7.347e-02
# Iter 100, loss = 9.389e-07
# 986
# Iter 0, loss = 1.823e-01
# Iter 100, loss = 1.801e-04
# Iter 200, loss = 5.860e-06
# Iter 300, loss = 4.616e-08
# 987
# Iter 0, loss = 9.665e-02
# Iter 100, loss = 1.088e-04
# Iter 200, loss = 2.081e-05
# Iter 300, loss = 2.991e-06
# Iter 400, loss = 1.050e-07
# 988
# Iter 0, loss = 1.634e-01
# Iter 100, loss = 3.807e-04
# Iter 200, loss = 7.116e-05
# Iter 300, loss = 7.319e-06
# Iter 400, loss = 3.959e-07
# Iter 500, loss = 1.475e-06
# 989
# Iter 0, loss = 8.427e-02
# Iter 100, loss = 1.017e-04
# Iter 200, loss = 1.246e-06
# 990
# Iter 0, loss = 9.438e-02
# Iter 100, loss = 1.706e-06
# 991
# Iter 0, loss = 8.715e-02
# Iter 100, loss = 1.008e-06
# 992
# Iter 0, loss = 1.532e-01
# Iter 100, loss = 2.441e-05
# Iter 200, loss = 7.841e-07
# Iter 300, loss = 1.207e-07
# Iter 400, loss = 1.221e-08
# 993
# Iter 0, loss = 8.071e-02
# Iter 100, loss = 1.357e-05
# 994
# Iter 0, loss = 8.651e-02
# Iter 100, loss = 8.862e-04
# Iter 200, loss = 3.047e-04
# Iter 300, loss = 1.007e-04
# Iter 400, loss = 3.437e-05
# Iter 500, loss = 1.065e-05
# Iter 600, loss = 2.987e-06
# Iter 700, loss = 4.574e-05
# Iter 800, loss = 1.617e-07
# Iter 900, loss = 9.959e-08
# 995
# Iter 0, loss = 1.801e-01
# Iter 100, loss = 5.259e-03
# Iter 200, loss = 3.694e-04
# Iter 300, loss = 1.949e-05
# Iter 400, loss = 1.497e-07
# 996
# Iter 0, loss = 1.429e-01
# Iter 100, loss = 2.818e-04
# Iter 200, loss = 5.361e-05
# Iter 300, loss = 9.048e-06
# Iter 400, loss = 1.053e-06
# Iter 500, loss = 1.078e-06
# 997
# Iter 0, loss = 9.812e-02
# Iter 100, loss = 5.455e-06
# 998
# Iter 0, loss = 9.936e-02
# Iter 100, loss = 2.054e-03
# Iter 200, loss = 1.581e-03
# Iter 300, loss = 1.173e-03
# Iter 400, loss = 8.471e-04
# Iter 500, loss = 5.921e-04
# Iter 600, loss = 4.022e-04
# Iter 700, loss = 2.531e-04
# Iter 800, loss = 1.995e-04
# Iter 900, loss = 7.906e-05
# 999
# Iter 0, loss = 1.267e-01
# Iter 100, loss = 5.582e-03
# Iter 200, loss = 4.783e-03
# Iter 300, loss = 3.987e-03
# Iter 400, loss = 3.233e-03
# Iter 500, loss = 2.513e-03
# Iter 600, loss = 1.838e-03
# Iter 700, loss = 1.188e-03
# Iter 800, loss = 6.486e-04
# Iter 900, loss = 2.975e-04

# %%
proj_star_arr = torch.stack(proj_star_arr)

# %%
plt.plot(proj_star_arr[y_ind0,0], proj_star_arr[y_ind0,1], "*")
plt.plot(proj_star_arr[y_ind1,0], proj_star_arr[y_ind1,1], "*")

# %%
ind_to_plot0 = list(set(motion_ind0) & set(context_ind0))
ind_to_plot1 = list(set(motion_ind1) & set(context_ind0))

plt.plot(proj_star_arr[ind_to_plot0,0], proj_star_arr[ind_to_plot0,1], "*")
plt.plot(proj_star_arr[ind_to_plot1,0], proj_star_arr[ind_to_plot1,1], "*")

ind_to_plot0 = list(set(color_ind0) & set(context_ind1))
ind_to_plot1 = list(set(color_ind1) & set(context_ind1))

plt.plot(proj_star_arr[ind_to_plot0,0], proj_star_arr[ind_to_plot0,1], "*")
plt.plot(proj_star_arr[ind_to_plot1,0], proj_star_arr[ind_to_plot1,1], "*")

# %%
ind_to_plot0 = list(set(motion_ind0) & set(context_ind0))
ind_to_plot1 = list(set(motion_ind1) & set(context_ind0))

plt.plot(proj_star_arr[ind_to_plot0,0], proj_star_arr[ind_to_plot0,2], "*")
plt.plot(proj_star_arr[ind_to_plot1,0], proj_star_arr[ind_to_plot1,2], "*")

ind_to_plot0 = list(set(color_ind0) & set(context_ind1))
ind_to_plot1 = list(set(color_ind1) & set(context_ind1))

plt.plot(proj_star_arr[ind_to_plot0,0], proj_star_arr[ind_to_plot0,2], "*")
plt.plot(proj_star_arr[ind_to_plot1,0], proj_star_arr[ind_to_plot1,2], "*")
# Out:
# '\nind_to_plot0 = list(set(color_ind0) & set(context_ind1))\nind_to_plot1 = list(set(color_ind1) & set(context_ind1))\n\nplt.plot(proj_star_arr[ind_to_plot0,0], proj_star_arr[ind_to_plot0,2], "*")\nplt.plot(proj_star_arr[ind_to_plot1,0], proj_star_arr[ind_to_plot1,2], "*")\n'

# %%
#infer stability at fixed points


def jacobian_and_eigs_at_fp(model, h_star, x_const=None, return_all=False, device='cpu'):
    """
    Compute Jacobian of F(h) = -h + J tanh(h) + B x + b at h_star,
    and return eigenvalues and diagnostics.
    """
    
    # ensure on device and correct shape
    h = h_star.clone().detach().to(device).reshape(-1)
    N = h.numel()

    # ensure model matrices on same device & detach to numpy later
    J = model.J_weights.detach().to(device)       # shape [N, N]
    b = model.bias.detach().to(device).reshape(-1)   # shape [N,]

    # compute r* = tanh(h*)
    r = torch.tanh(h)

    # phi = 1 - r^2
    phi = (1.0 - r**2).reshape(-1)   # shape [N,]

    # build diag(phi) as a (N,N) tensor
    D = torch.diag(phi)   # (N,N)

    # Jacobian: -I + J @ D  (matches dF/dh_i_k = -delta_ik + J_ik * phi_k)
    I = torch.eye(N, device=device)
    Jc = -I + J @ D   # (N,N), continuous-time Jacobian

    # convert to numpy for eigendecomposition (move to cpu first)
    Jc_np = Jc.cpu().numpy()

    # eigenvalues and eigenvectors
    eigvals, eigvecs = np.linalg.eig(Jc_np)   # eigvals complex

    # discrete map eigenvalues for your update h_new = h + s * F(h)
    s = float(model.dt) / float(model.tau)
    M_np = np.eye(N) + s * Jc_np
    mu_vals, mu_vecs = np.linalg.eig(M_np)

    # diagnostics
    max_real = eigvals.real.max()
    spectral_radius = np.max(np.abs(eigvals))
    num_unstable_cont = (eigvals.real > 0).sum()          # eigenvalues with positive real part
    num_unstable_disc = (np.abs(mu_vals) > 1.0).sum()     # discrete update unstable modes

    report = {
        'N': N,
        's': s,
        'max_real_part_continuous': float(max_real),
        'spectral_radius_continuous': float(spectral_radius),
        'num_unstable_continuous': int(num_unstable_cont),
        'num_unstable_discrete': int(num_unstable_disc),
        'eigvals_continuous_sample': eigvals[:10],   # first few (for quick glance)
        'mu_vals_discrete_sample': mu_vals[:10],
    }

    if return_all:
        return Jc, eigvals, eigvecs, mu_vals, mu_vecs, report
    else:
        return eigvals, mu_vals, report
